# %%
# !python --version
# Out:
# Python 3.7.3

# %%
# !pip install -q -U pip --ignore-installed wrapt enum34 simplejson netaddr
# !pip install -q numpy
# !pip install -q pandas
# !pip install -q ckiptagger
# !pip install -q tqdm
# !pip install -q tensorflow==1.14.0
# !pip install -q ipywidgets

# %%
import pandas as pd
import numpy as np

from ckiptagger import WS, POS
from tqdm.notebook import tqdm

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train
# Out:
#       index class                                     title
# 0         0    體育                  亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1         1    體育                 9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2         2    體育                      如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3         3    體育                     超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4         4    體育                   騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍
# 5         5    體育                       如果朗多進入轉會市場，哪些球隊適合他？
# 6         6    體育                             詹姆斯G3決殺，你怎麼看？
# 7         7    體育            大魔王帶頭唱歌！火箭這像是打季後賽？爵士神帥這話已提前投降了
# 8         8    體育          馬夏爾要去切爾西？可以商量，不過穆里尼奧的要價是4000萬加威廉
# 9         9    體育                    利希施泰納宣佈賽季結束後離隊：我需要新的挑戰
# 10       10    體育                 怎麼樣看待大連一方在中超聯賽第九輪取得的賽季首勝？
# 11       11    體育            科勒·卡戴珊與男友TT共進午餐，曾在他懷孕期間偷腥的渣男被原
# 12       12    體育           作為央視體育體育頻道，CCTV5一到週末就直播馬拉松你怎麼看？
# 13       13    體育                如果2018騎士奪冠，詹姆斯這個冠軍的含金量有多大？
# 14       14    體育                昔日中超金靴半場獨造6球虐爆遼足 華夏送走他後悔嗎？
# 15       15    體育                             NBA歷史排名前十都有誰？
# 16       16    體育               你希望利物浦贏得歐冠嗎？巴薩主帥巴爾韋德的回答耐人尋味
# 17       17    體育            絕殺！詹姆斯38+7再創傳奇一刻，兩護法創另類神跡更功不可沒
# 18       18    體育                             再現絕殺！今天的老詹怎麼吹
# 19       19    體育                        拜仁3比1逆轉科隆，J羅現世界級做餅
# 20       20    體育                   白送一個點球！恆大都不要？卡納瓦羅笑容真有意思
# 21       21    體育       劉詩雯戴罪立功取勝平野美宇為中國女乒拿到世乒賽冠軍，怎麼看待這場比賽？
# 22       22    體育                 天堂與地獄是有多近？看看比賽最後8秒的猛龍就知道了
# 23       23    體育                                   魯能隊員的身高
# 24       24    體育                   WKG&M-1世界綜合格鬥賽明星見面會引爆鵬城
# 25       25    體育                      如何看待第一詹黑皮爾斯，公開贊美詹姆斯？
# 26       26    體育                            粵媒：缺少外援的恆大還是不行
# 27       27    體育                    熱刺作死的節奏！連墊底隊都輸，歐冠席位懸了？
# 28       28    體育             德帥談沒球隊面試布茲德里克：出於自私的原因，他在這讓我開心
# 29       29    體育                         雙刃劍！山東魯能高中鋒讓人又愛又恨
# ...     ...   ...                                       ...
# 1770   1770    遊戲         怎麼看微博大V爆料王者掉幀卡頓等問題是因為手機品牌保護費交的不夠？
# 1771   1771    遊戲                   王者榮耀一些知名主播為什麼不選擇加入職業戰隊？
# 1772   1772    遊戲            Uzi億元續約虎牙直播，明晚虎牙開播倒計時，各種好禮等你來拿
# 1773   1773    遊戲         怎麼看微博大V爆料王者掉幀卡頓等問題是因為手機品牌保護費交的不夠？
# 1774   1774    遊戲             真·國服第一諾手問世？余小C韓服王者600點諾手豪取五殺！
# 1775   1775    遊戲                  RNG官博放出最新片花，唯獨少了正在直播的Uzi
# 1776   1776    遊戲          LOL：亞索第一次在2018MSI登場？KBM完美應對擊敗DW！
# 1777   1777    遊戲                  小智三年坐穩全民一哥，而她成為一姐只用了三個月！
# 1778   1778    遊戲          Lol里支援速度最快的3個英雄，死歌和慎上榜，第1個對面看到就煩
# 1779   1779    遊戲             王者榮耀：這四名英雄必被ban！榮耀王者到底有多討厭他們？
# 1780   1780    遊戲              DNF「玩家花錢在網上買了個號」為了防止找回，直接毀號！
# 1781   1781    遊戲        英雄聯盟閃電狼FW戰隊到達柏林準備MSI，他們進入正賽的可能性多大？
# 1782   1782    遊戲                     王者榮耀，哪吒唱起五環之歌，安琪拉摘星星！
# 1783   1783    遊戲            王者榮耀：小學生到底該不該出現在王者峽谷？看完這四點你就明白
# 1784   1784    遊戲                             劍仙和張大仙有什麼不同呢？
# 1785   1785    遊戲                      預算7000元左右，是買遊戲本還是主機？
# 1786   1786    遊戲                             長期打遊戲對你有什麼影響？
# 1787   1787    遊戲                             300英雄狗年會有活動嗎？
# 1788   1788    遊戲             dnf童話妖精養成記活動怎麼玩？妖精成長積分可兌換獎勵介紹
# 1789   1789    遊戲          王者榮耀：S11賽季特別要注意的事情，敢說這4個字，直接扣分封號
# 1790   1790    遊戲         DNF 總算有個號閃了萬世三件套 感覺好受傷啊 俺們運氣是有多坑啊
# 1791   1791    遊戲                  為什麼玩穿越火線，有的人打死人後老是喜歡換子彈？
# 1792   1792    遊戲  eStarPro vs WF.D前瞻：背水一戰，WF.D脫離保級區之路任重而道遠
# 1793   1793    遊戲                    聯發科P60八核讓OPPO R15吃雞更流暢
# 1794   1794    遊戲                   夢幻西游這幾天連出三把專用，現在已經很難取捨了
# 1795   1795    遊戲           LOL：麻辣香鍋韓服Rank不合成打野刀？電刀巨魔新套路連勝中
# 1796   1796    遊戲                     穩住，我們能贏！因為我們擁有這種強大的力量
# 1797   1797    遊戲                   騰訊是怎樣毀掉《鬥戰神》這款可能成神的作品的？
# 1798   1798    遊戲                            LOL你不知道的黑科技打法！
# 1799   1799    遊戲                          遊戲拳皇各代的劇情都在講些什麼？
#
# [1800 rows x 3 columns]

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
ws = WS('./data/')
pos = POS('./data/')

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):
    word_s = ws([title])
    word_p = pos(word_s)
    # YOUR CODE HERE

    # END YOUR CODE
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    word_s = ws([title])
    word_p = pos(word_s)
    # YOUR CODE HERE

    # END YOUR CODE
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
train_title_cuts[120]
# Out:
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
index2word = {}
# 產生字與index對應的關係
n = 0
for index in train_title_cuts:
    for word, flag in train_title_cuts[index]:
        if word not in word2index:
            word2index[word] = n 
            index2word[n] = word
            n += 1

# %%
word2index['溫暖']
# Out:
# 1520

# %%
index2word[1520]
# Out:
# '溫暖'

# %%
def get_bow_vector(pairs, word2index):
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index:
            vector[word2index[word]] += 1
    return vector

# %%
get_bow_vector(train_title_cuts[120], word2index)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items():
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['林美景', '尤納斯', '賞月夜', '朱婷', '伏爾加格勒', '阿迪薩亞', '賈躍亭', '浦發', '億航', '重渡溝', '傑森', '羅', '內馬爾', '清華', '李白界', '郭煒煒', '李秋平', '娜迦王海伯倫', '韓信', '埃爾克森', '杜蘭特', '微博', '亨德森', '圍甲', '雷軍', '國四', '聯盟里', '萊萬特', '阿木木歷', '侯森', '北京人和', '華峰', '大豐', '英超', '火箭隊', '迪士尼', '郎平', '逆水寒', '扎堆', '約翰塞納', '詹姆斯', '萊科寧', '山東隊', '西蒙斯', '皇馬', '上港', '胤祥', '吉尼斯', '溫格', '力帆', '泰森', '高曉松', '楊帆', '哪吒', '馬夏爾', '老詹', '萬孚', '奧拉朱旺', '瓦基弗', '阿里舜宇', '張呈棟', '靜懿', '卡拉黑', '德羅贊', '雷霆隊', '許', '盧', '藍星', '郭躍', '張大仙', '璞麗', '唐培科', '劉偉', '意大利杯', '施之皓', '昂科威', '堪比比薩', '權健', '詹', '海爾', '林斌', '裴擒虎', '威廉姆斯', '沙特', '劉集', '英特爾', '雲聯惠', '老馬', '拉基蒂奇', '樸泰夏', '威少', '劉德華', '東決', '小明', '微星', '巴菲特', '施泰納', '洛瑞', '遼足', '李嘉誠']
# =======================
# VC : ['賣出', '丟', '開展', '撫摸', '耍', '練到', '縊縮', '翻譯', '救贖', '攻', '帶', '打開', '參透', '融入', '外接', '辦', '應用', '招待', '檢驗', '啓定', '迎接', '幫助', '採摘', '賒', '提升', '撒', '精選', '考察', '擴種', '反擊', '參加', '包裝', '毀滅', '養成', '執行', '回應', '牽頭', '採取', '宣一', '發推', '抓', '取消', '戰釀', '照看', '論', '看', '打通', '玩', '踢到', '擺出', '娶', '監管', '防守', '通過', '單殺', '接近', '送別', '加強', '選擇', '留下', '添脫', '養活', '帶來', '喜出', '決殺', '衝施', '掀', '栽賣', '做好', '吃完', '奪得', '超越', '過上', '揭秘', '處理', '體驗', '改動', '帶火', '團購', '支持', '戲耍', '徵召', '追', '渲染', '保駕', '打到', '欺騙', '擒', '實拍', '開好', '攜驅', '打響', '支援', '治療', '抓住', '突破', '拍到', '安裝', '實施', '移']
# =======================
# Na : ['痛點', '良心', '蔬菜', '總書記', '神', '買賣盤', '工匠', '環', '樹', '關鍵', '王朝', '天價', '國家', '券商', '狙擊槍', '官方', '重拳', '黑屏', '姐', '可能', '習俗', '聊城人', '果農', '不良率', '規模', '眼睛', '球迷', '工工資', '進展', '女兒', '背景', '用藥', '缺口', '服務員', '鏡', '哲學', '體育', '足球', '積分', '低頻', '期貨', '畫像', '流量', '直面', '皇家', '譜', '實力', '正負值', '新機', '大地', '淚', '竹絲', '大小苗', '濾鏡', '網約車', '標華', '內幕', '黑客', '對比', '女排', '發酵劑', '狂風', '排行榜', '猛龍內線', '木材', '天命杯', '小花生', '聯網', '貓神', '框架', '搖錢樹', '百香', '鄉土', '半導體', '現實', '五行', '國乒女隊', '問題', '火力', '高峰', '股東', '榮譽', '戰隊', '卷葉', '小額', '人才', '，碼商', '數字幣', '鴨脖', '熱潮', '信息', '競爭', '中藥', '子女', '隊友', '姓', '言論', '項目', '文章', '房客']
# =======================
# COLONCATEGORY : [':', '：']
# =======================
# Nc : ['公司', '華池縣', '鎮', '里貝里', '外地', '巴西', '火山口', '九寨溝', '地上', '貴陽市', '縣里', '博物館', '袁家村', '雪鄉', '法國', '超大陸', '利物浦', '我國', '泰國', '台南', '背後', '洛陽', '哈爾濱', '農場', '窗口', '兩岸', '亞索', '阜南縣', '宿城', '廣東', '富縣', '瀋陽', '大連海', '開灤', '浩特', '咸陽', '市場', '傢具店', '南山', '酒館', '優區', '豬場', '佛山', '北侖', '球場', '奧蘭多', '湖北', '漁場', '永城', '泰拉瑞亞', '場', '茶鄉', '城鎮', '浙江', '中國', '大理', '滕州', '大洲島', '華山', '上海', '懸崖', '塔昌村', '轄區', '中心', '賽區', '酒店', '股市', '杭州', '港交所', '果園地', '越南', '仁壽', '金融城', '馬刺', '新疆', '四川', '火車站', '塞班', '成中路', '湖南省', '牛排館', '國', '楚河', '荒山', '人區', '主題店', '阿拉德', '雲端', '瑞士', '培田', '馬略卡島', '雷區', '民間', '年畫村', '朝邑鎮', '早市', '霞飛', '呼和', '南陽', '浙里']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['再見', '退款', '領銜', '退貨', '執教', '加油', '加工', '加起來', '一網打盡', '入賬', '分段', '復仇', '罰款', '收回來', '分紅', '融資', '通話', '定位', '效力', '鍍金', '解體', '計算出來', '上架', '解惑', '退改', '鋪平', '提前', '騙錢', '代打', '抓來', '相比', '加持', '加冕', '充氣', '充飢', '扣分', '開戰', '應對', '分組', '導航', '護航', '站台', '罵屌絲', '助威', '解圍', '拍照', '解密']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['隨地', '大規模', '一頭', '怎麼', '多多', '快', '急劇', '差點', '相', '總會', '有沒有', '差點兒', '再次', '原來', '大都', '曾', '能否', '大力', '自然', '皆', '會', '還是', '帶頭', '可能', '究竟', '硬生生', '迫不及待', '均', '再', '沒想到', '來', '還可以', '只有', '為啥', '怎能', '超級', '已經', '一直', '時刻', '變相', '難以', '越', '總', '好像', '驟然', '已然', '結伴', '未必', '不得不', '是否', '應該', '需', '常', '即', '一', '這麼', '大幅', '大概', '反野', '去', '首', '不會', '盡情', '如何', '常常', '可以', '本來', '並', '就', '別', '何以', '可否', '從來', '每', '盡', '還', '在', '隆', '居然', '不', '趕緊', '能夠', '從', '全程', '所', '悄悄', '一一', '也', '一起', '立即', '仍然', '能', '只是', '真是', '首次', '竟', '該', '從中', '沒', '能不能']
# =======================
# P : ['如', '等', '繼', '用', '比如', '到', '除', '除了', '像', '隨了', '跟', '幫', '直至', '就', '遭', '自', '針對', '在', '把', '往', '被', '從', '當', '給', '為了', '按', '為', '對', '至', '距離', '於', '自從', '關於', '受', '憑', '離', '和', '以', '比', '根據', '隨', '趁', '靠', '因', '與', '向', '將', '趁著', '慘遭', '待', '臨']
# =======================
# VG : ['如', '評選', '變成', '屈居', '像', '當成', '稱', '做', '應聘', '當作', '彷彿', '排行', '化', '排', '算', '當', '形成', '成', '非', '類似', '合成', '為', '變', '稱為', '姓', '算是', '竟是', '酷似', '充當', '叫', '做成', '似', '稱得上', '改造成', '屬於', '封號', '理解為', '戰成', '美成', '建成', '升任', '排名', '賣成', '投票成', '成為', '當上', '叫做', '並列', '等於', '猶如', '作為', '居', '譽為', '名叫', '稱作', '堪稱', '集成', '疑似', '誤認成']
# =======================
# Neu : ['4萬多', '三千億', '8', '十多萬', '千', '第四十四', '3-0', '32', '9', '150', '500', '零', '四五', '98', '180萬', '13', '第36', '六', '2', '1', '76', '0:3', ' 360', '14億', '百萬', '2:1', '5050', '600', '50萬', '15', '58', '數千萬', '711', '12', '25', '00', '0:0', 'b120', '47億', '700', '17', '2000', '2.37億', '千千萬', '24.8億', '35萬', '第3', '第十四', '500萬', '2018.', '010', '第一', '300', '3', '2.93億', '3.5', '9-0', '24億', '1.1.2', '一', '4', '1299', '10010', '5', '一百', '6.9', '第33', '千億', '8萬', '980', '80', '200', '兩', '4G+64', '十億', '第七', '（二）', '23萬一', '15萬', '三', '115', '萬億', '4.7億', '第四', '1200億', '845', '十三', '90', '5萬', '一500', '（四）', '1318', '37', '22', '48', '38', '3000', '(00926)', '20萬', '八']
# =======================
# Nf : ['英吋', '層', '招', '篇', '港元', '公里', '票', '槍', '張', '局', '鍋', '群', '週', '回', '分鐘', '分', '套', '盤', '日', '頓', '級', '期', '行', '則', '輪', '頁', '斤', '隻', '屆', '所', '場', '胎', '處', '掛', '米', '頭', '條', '種', '刻', '本', '秒', '度', 'K', '口', '部', '串', '色', '些', '歲', '晚', '塊', '批', '畝', '個', '隊', '遍', '件', '類', '對', '毛', '輛', '筆', '座', '項', '戶', '棵', '檔', '噸', '關', '節', '元', '號', '路', '款', '支', '家', '片', '把', '股', '門', '道', '年', '美元', '天', '番', '班', '碗', '株', '次', '位', '方', '只', '名', '句', '袋', '步', '樣', '台', '點', '周']
# =======================
# VJ : ['服', '超', '領略', '透', '懼怕', '煥發', '自有', '忽略', '分享', '平', '不理', '忽視', '贊同', '為', '賽', '痛失', '歸屬於', '過完', '從事', '失', '不如', '遺傳', '近', '欣賞', '納入', '受', '吸引', '年入', '限', '失去', '缺', '優於', '大勝', '要價', '維持', '贏得', '熱心', '共有', '新增', '展望', '心疼', '擁有', '震撼到', '認', '佔', '歸', '超過', '負於', '蘊藏', '沒', '抗', '不到', '錯失', '出身', '身臨', '順應', '得', '認識', '無', '減持', '喪失', '符合', '強過', '發揮', '領先', '僅次', '降至', '適用', '替代', '高達', '看懂', '爆發', '惜', '輸掉', '逾', '享受', '脫', '缺少', '錯過', '曬', '看好', '充', '同情', '出於', '歡迎', '關注', '養有', '僅次於', '持有', '毫無', '出', '晉級', '沈迷', '處於', '緊缺', '經歷', '領跑', '入選', '耗', '虧損']
# =======================
# VD : ['予', '寄予', '拒賠', '發放', '收費', '還', '白送', '輸', '提供', '給', '禁售', '借貸', '速遞', '送', '借', '坑', '配', '輸給', '轉讓', '贏', '搶', '支付', '郵給', '貸款', '欠', '付', '清繳', '分', '發給', '補貼', '給予', '賣', '供應', '發', '售', '貸', '交付', '傳', '補繳']
# =======================
# Dfa : ['超', '遠遠', '如此', '更', '太', '同樣', '越來越', '還', '不大', '最', '較', '很', '有點', '遠', '過', '有些', '頗', '十分', '多', '過於', '更為', '還要', '極', '非常', '這麼', '好', '比較']
# =======================
# VH : ['舊', '短', '掉', '努力', '廉價', '茫然', '低開', '相應', '難', '嚴重', '竊喜', '常見', '重重', '年久失修', '致富', '漲停', '迅速', '對了', '普遍', '機智', '密集', '划算', '榮幸', '原始', '多彩', '繁多', '漲停板', '狠', '合適', '大', '大跌', '一樣', '色綠', '老', '好吃', '還可以', '忙', '苦不堪言', '實際', '無解', '太少', '暖', '火', '獲利', '合格', '迷你', '高', '實惠', '富奔', '頻發', '乾淨', '爭相鬥艷', '出全', '極好', '不見了', '丟臉', '害羞', '減產', '安全', '無效', '特殊', '開始', '辛勞', '別樣', '時髦', '不對勁', '偉大', '厲害', '廣大', '見分曉', '平平無奇', '免費', '眾多', '值錢', '閃現', '著急', '發熱', '酷', '犀利', '逾期', '有情', '淡定', '不錯', '暢快', '便宜', '良好', '百出', '正常', '巨大', '發燒', '同步', '齊', '通貨膨脹', '墮落', '凝重', '蓄勢待發', '深入', '復出', '得寸進尺', '滿滿']
# =======================
# Cbb : ['既然', '不僅', '不過', '假如', '並', '因為', '可是', '如果', '並且', '反而', '雖然', '即使', '不管', '而是', '還不如', '縱使', '不如', '但', '只有', '但是', '另外', '就算', '既', '只要', '因', '連', '跟著', '要是', '而', '不然', '否則', '若']
# =======================
# Nd : ['季度', '晚間', '花季', '2035年', '4月', '2018年度', '5.7日', '下旬', '六', '荒古', '小時候', '5月', '一下', '季', '10點', '2018年', '熱天', '旅遊節', '00年', '明晚', '五月', '九月', '夏季', '五月份', '早晨', '5日', '何時', '臨時', '雍正', '正月', '90年', '15日', '一大早', '15年', '多久', '以前', '6月', '秋', '當時', '12日', '寒武紀', '月季', '31號', '大中', '週二', '2017年', '那時', '7號', '永久', '米節', '如今', '春季', '相親節', '2019', '夏天', '採摘節', '4日', '晚上', '過去', '後來', '週末', '明日', '06日', '短期', '立夏', '今夏', '今日', '最近', '今年', '中期', '1點', '夏', '5月份', '2005年', '2018', '現代', '現在', '近日', '05月', '夏日', '明', '晚清', '8日', '昔日', '1990年', '夜', '春天', '3月', '文化節', '2019年', '首日', '6日', '狗年', '秋季', '1日', '長期', '19年', '最後', '一會', '5號']
# =======================
# VA : ['目不暇接', '拍案叫絕', '出台', '下場', '翻曬求籽', '奔馳', '發家', '擾民', '游水', '成交', '炒股', '代工', '開課', '飆車', '進貨', '產仔', '結果', '壓槍', '下卡', '進去', '減稅', '充電', '表態', '跳', '徒步', '上升', '脫坑', '墊腳', '翻身', '派息', '求生', '倒下', '轉農', '點球', '出門', '出發', '啓動', '盤旋', '創業', '郊遊', '遊玩', '幹什麼', '打顫', '做生意', '下降', '放光', '收錢', '簽約', '現身', '掃碼', '抓頂', '報警', '奪冠', '開團', '報關', '避暑', '醫人', '代言', '鬥勇', '下雪', '扶貧', '通信', '搭檔', '起飛', '大笑', '格鬥', '奔', '抽籤', '加時', '探秘', '理財', '付錢', '開店', '騎車', '爭霸', '餵尿素', '掙扎', '蹲坑', '播種', '漂流', '睡', '打板', '開盤', '來襲', '探界', '開播', '做種', '會師', '佈局', '搞笑', '出單', '血刃', '養花', '游', '拼房', '壓哨', '招商', '打麻將', '來', '募資']
# =======================
# COMMACATEGORY : [',', '，']
# =======================
# Nes : ['首', '本', '各', '近', '後', '上', '某', '貴', '每', '頭', '另', '何', '下', '同', '前', '該']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# EXCLAMATIONCATEGORY : ['!', '！']
# =======================
# Di : ['個', '了', '著', '起來', '過']
# =======================
# Nep : ['那', '哪', '其', '此', '啥', '其中', '什麼', '這']
# =======================
# Caa : ['到', '至', '比', 'VS', '或者', '或是', '跟', '與', '及', '又', '還是', '暨', '或', '和']
# =======================
# VCL : ['遊覽', '住', '存進', '到', '盤踞', '走下', '留在', '用於', '赴', '深入', '栽進', '蒞臨', '走訪', '走過', '橫掃', '穿透', '回歸', '進入', '走進', '在', '往', '抵達', '退出', '玩遍', '度過', '穿過', '來到', '遠離', '過', '到達', '跌出', '暗渡', '入', '出', '升至', '重返', '路過', '前來', '回', '重回', '登陸', '穿越', '前往', '上', '進', '直達', '跌至', '回到', '出發到', '走到', '去']
# =======================
# Neqa : ['6%', '三分之一', '滴滴', '100%', '9.89%', '半', '一點', '0.8%', '步步', '其他', '許多', '8%', '15%', '有的', '任何', '個個', '80%', '更多', '四成', '很多', '百分之八十', '大量', '哪些', '一處處', '這麼多', '大多', '句句', '無數', '90%', '遍', '有些', '67%', '全', '多', '部分', '多點', '所有', '那些', '1/4', '41.8%', '1%', '多少', '20%', '大多數', '其它', '30%', '不少', '一切', '一半', '12%', '一些', '10%', '這些']
# =======================
# Nh : ['本人', '大家', '雙方', '它們', '自我', '我', '他', '她', '一方', '父子倆', '個人', '屌絲', '他們', '俺們', '各自', '自己', '它', '小眾', '我們', '誰', '自身', '你們', '你', '別人', '她們', '各位', '私人', '人家', '對方', '您']
# =======================
# FW : ['King James', ' CCR', 'TT', 'ADC', 'iPad', '<', 'U23', 'PS', 'CP', ' 樂', 'MSCI', 'N7', 'FF ', 'raid', 'QGhappy', 'Aloha', '2', 'G', 'IOS', 'Fullestop', 'BAT', 'LOL：', 'UZI', 'eStar', 'BTC', 'FOF', '9A91', 'OPPO R', 'iphone6plus', 'Mc', 'KPL', 'Soloking', 'iPhone X', '：BTC', 'Alan', 'AG', '：AG', 'shou', 'DOTA2 ', 'AD', 'dnf', 'eStarPro vs WF.D', 'Nvidia', 'CBA', 'CFO', 'CPI', 'RNG', '8d', 'IP', 'cosplay', 'OB', 'OTT', 'max2', 'VR ', 'G+', 'vs', 'l ', 'PGM 0-1 SUP', 'KV', '-6', '~', 'mix2', 'lck', 'PVE', 'Day', 'FPP', 'numb', 'i7', 'Rank', 'h', 'CDR', 'OV', 'HTC', 'NBA ', 'SUP', 'AMD', ' vs 利物浦', 'LOL：MSI', 'NPC', 'XQ', 'IG', ' 28', 'iPhone X Plus', 'Rookie', 'OMG', 'Lol里', '+4', 'CCR', 'MARVEL X', 'msi', 'kpl', 'J', ' 利', 'Oeanc', 'SSR', '―', 'e', '-0', 'qq', 'WF']
# =======================
# SHI : ['像是', '是']
# =======================
# VE : ['自嘲', '預告', '抱怨', '說', '稱', '防止', '確認', '提到', '看看', '猜', '見到', '准', '探索', '討說', '發佈', '提', '爆料', '深思', '告訴', '安排', '幻想', '樂見', '限制', '研究', '查', '介紹', '公佈', '呼籲', '預計', '聽', '感嘆', '判定', '調研', '考慮', '要', '訴說', '提猜', '見', '探討', '聯想', '見證', '暗示', '發現', '判罰', '管', '想', '報道', '看出', '提起', '預測', '預期', '宣佈', '假設', '做到', '提醒', '公告', '形容', '發誓', '揭曉', '允許', '看清楚', '算', '商量', '公認', '回顧', '想起', '公示', '廣播', '回答', '預防', '反對', '識別', '以為', '講解', '知詢', '申卡', '禁止', '炫耀', '呼', '慶祝', '賭約', '披露', '傳聞', '精准', '檢測', '示範', '查看', '聽到', '估值', '談', '問', '避免', '想到', '講', '聽說', '查找', '盛贊', '想要', '說明', '想好']
# =======================
# DE : ['地', '得', '的', '之']
# =======================
# VHC : ['機構化', '擴張', '冷卻', '暫停', '降低', '團結', '開', '震驚', '停', '國際化', '恢復', '加快', '可憐', '產生', '公開', '增 ', '辛苦', '下來', '煩', '溫暖', '減少', '穩定', '肥', '繁榮', '普及', '滿足', '斷', '淡化', '增長', '還原', '結束', '智能化', '變動', '增加', '破', '愁壞', '壞', '增強', '規模化', '凍', '麻煩', '現代化', '感動', '強化', '熱', '陷', '告破', '優化', '平衡', '愁死', '縮小', '豐富', '傷']
# =======================
# Ng : ['而言', '左右', '初', '之內', '之後', '間', '以上', '外', '時', '下', '以外', '之外', '中', '以後', '之下', '之上', '之前', '之間', '前', '底', '來', '以下', '以來', '內', '起', '般', '裡', '後', '上', '為止', '之中']
# =======================
# VK : ['懷疑', '知', '想見', '怕', '瞭解', '有利於', '擔心', '感謝', '忘', '奇怪', '害怕', '顯示', '懂', '期待', '欲', '不忘', '回憶', '指望', '知道', '小心', '願意', '恨', '意想不到', '遇', '希望', '意味', '感受', '意外', '懂得', '依賴', '明白', '同意', '抱歉', '確定', '願', '感覺', '理解', '覺得', '盼', '遺憾', '討厭', '喜歡', '信', '肯定', '堅持', '面臨', '流傳', '忘記', '介意', '曲解', '所謂', '需', '覺', '感覺到', '恐', '需要', '不滿', '放心', '注意']
# =======================
# Ncd : ['那裡', '東方', '間', '外', '末端', '下', '裡面', '中間', '中', '東西部', '哪', '哪兒', '東', '哪裡', '前沿', '北', '哪下', '以下', '這裡', '上方', '內', '方', '邊', '畔', '東部', '裡', '旁邊', '西', '當中', '一帶', '底部', '上', '兩旁', '上面', '中部', '對面', '外面', '西部', '那邊']
# =======================
# A : ['小本', '前置', '獨家', '乒乓', '主', '超', '獨門', '寶有', '現役', '後置', '新一代', '彩色', '麻辣', '雙', '二手', '額外', '中', '最佳', '同等', '非', '火紅', '重磅', '必備', '獨角', '一般', '基層', '業餘', '高度', '國產', '上上', '眾', '地下', '綜合', '超級', '現行', '歐式', '真正', '唯一', '碧藍', '單', '常務', '共同', '總', '多餘', '優質', '大幅度', '野生', '同一', '原', '基礎', '長途', '頭號', '中西', '新興']
# =======================
# V_2 : ['有']
# =======================
# VL : ['使得', '愛好', '故意', '致', '持續', '開始', '能', '習慣', '趨於', '不惜', '用來', '令', '喜好', '敢', '讓', '肯', '導致', '甘願', '便利', '使', '愛', '後悔']
# =======================
# T : ['嗎', '去', '麼', '啊', '來', '的', '哪', '了', '嘛', '咯', '啦', '呢', '吧', '哦', '矣']
# =======================
# VI : ['驚艷', '傾心', '取勝', '著稱', '專用']
# =======================
# DASHCATEGORY : ['-', '—']
# =======================
# I : ['瑪法里奧', '哦']
# =======================
# Dk : ['想不到', '那', '據說', '據聞', '反過來', '外傳', '那麼', '結果']
# =======================
# VF : ['繼續', '勸住', '打算', '申請', '要求', '試試', '鼓勵', '判', '帶領', '準備', '拒', '止住', '拒絕', '策劃', '助', '叫', '催', '率領', '推選', '擬', '請', '勸說', '告誡', '逼', '試', '邀', '停止', '圖']
# =======================
# Da : ['正好', '僅', '不下', '近', '唯獨', '才', '足足', '幾近', '只', '約', '光', '共', '幾乎', '將近', '最多']
# =======================
# PARENTHESISCATEGORY : ['(', '（', '「', '》', '」', '《', '）']
# =======================
# Nv : ['登山', '錄制', '翻譯', '創業', '航海', '管理', '關聯', '絕殺', '惡搞', '射擊', '回歸', '抗戰', '推薦', '問', '開發', '私募', '生產', '疊加', '度假', '燃燒', '思考', '解救', '配置', '買單', '護髮', '營銷', '體驗', '分銷', '輔助', '防治', '判罰', '訴訟', '代理', '灌籃', '遊樂', '經歷', '崩潰', '銷售', '研究', '供電', '工作', '兼職', '組合', '增發', '批發', '旅遊']
# =======================
# PERIODCATEGORY : ['·', '。']
# =======================
# VAC : ['集合', '上演', '動', '推進', '蒸發', '移動']
# =======================
# Dfb : ['極了', '些', '一點']
# =======================
# Cab : ['等', '等等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['以上', '半', '多', '幾']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        'Nh', 'Nep', 'Nes', 'DE', 'T', 'P', 'V_2', 'SHI',
        'Dfa', 'Dfb', 'Da', 'Di', 'Dk',
        'Caa', 'Cab', 'Cba', 'Cbb',
        'COLONCATEGORY', 'COMMACATEGORY', 'DASHCATEGORY', 'DOTCATEGORY', 'ETCCATEGORY', 'EXCLAMATIONCATEGORY',
        'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'PERIODCATEGORY', 'QUESTIONCATEGORY', 'SEMICOLONCATEGORY',
        'SPCHANGECATEGORY', 'WHITESPACE'
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %% [markdown]
# # Cosine Similarity

# %%
def cosine_similarity(bow1, bow2):
    similarity = np.sum(bow1 * bow2) / (np.sqrt(np.sum(np.square(bow1))) * np.sqrt(np.sum(np.square(bow2))))
    return similarity

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'體育': array([0.04      , 0.01333333, 0.00333333, ..., 0.        , 0.        ,
#         0.        ]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00333333, 0.00333333,
#         0.00333333])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 73, '遊戲': 8, '財經': 6, '旅遊': 6, '農業': 6, '科技': 3})
# predict 財經 :  Counter({'財經': 67, '科技': 18, '體育': 6, '旅遊': 6, '遊戲': 6, '農業': 5})
# predict 科技 :  Counter({'科技': 62, '財經': 13, '體育': 10, '農業': 6, '遊戲': 6, '旅遊': 2})
# predict 旅遊 :  Counter({'旅遊': 70, '農業': 11, '財經': 6, '科技': 3, '遊戲': 2})
# predict 農業 :  Counter({'農業': 70, '旅遊': 9, '科技': 6, '體育': 5, '財經': 4, '遊戲': 3})
# predict 遊戲 :  Counter({'遊戲': 75, '科技': 7, '旅遊': 5, '體育': 4, '財經': 4, '農業': 1})
