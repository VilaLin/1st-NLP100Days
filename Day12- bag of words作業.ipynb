# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n 
    index_word[n] = word
    n+=1

# %%
word_index
# Out:
# {'downright': 0,
#  'my': 1,
#  'can': 2,
#  'incredibly': 3,
#  'treated': 4,
#  'Gold': 5,
#  'beer': 6,
#  'hurry': 7,
#  'wide': 8,
#  'Same': 9,
#  'paper': 10,
#  'myself': 11,
#  'somethat': 12,
#  'spot': 13,
#  'mains': 14,
#  'Furthermore': 15,
#  'hilarious': 16,
#  'best': 17,
#  'saving': 18,
#  'definitely': 19,
#  'legit': 20,
#  'fabulous': 21,
#  'mouth': 22,
#  'warm': 23,
#  'Risotto': 24,
#  'been-stepped-in-and-tracked-everywhere': 25,
#  'desserts': 26,
#  'free': 27,
#  'deliciously': 28,
#  'box': 29,
#  '1': 30,
#  'happened': 31,
#  'Casino': 32,
#  'salads': 33,
#  'complain': 34,
#  'bartenders': 35,
#  'plethora': 36,
#  'bigger': 37,
#  'Things': 38,
#  'getting': 39,
#  'been': 40,
#  'Boy': 41,
#  'owners': 42,
#  'reviewer': 43,
#  'Nan': 44,
#  '11.99': 45,
#  'tea': 46,
#  'do': 47,
#  'life': 48,
#  'drunk': 49,
#  'pictures': 50,
#  'We': 51,
#  'tacos': 52,
#  'Bloody': 53,
#  'specials': 54,
#  'least': 55,
#  'impressed': 56,
#  'tragedy': 57,
#  'Maria': 58,
#  'freaking': 59,
#  'handmade': 60,
#  'Nothing': 61,
#  '.THE': 62,
#  'Gordon': 63,
#  'Try': 64,
#  'were': 65,
#  'beans': 66,
#  'focused': 67,
#  'our': 68,
#  'blanket': 69,
#  'Update': 70,
#  'mouths': 71,
#  'liked': 72,
#  'elsewhere': 73,
#  'combination': 74,
#  'coffee': 75,
#  'companions': 76,
#  'compliments': 77,
#  'mmmm': 78,
#  'his': 79,
#  'ok': 80,
#  'fail': 81,
#  'someone': 82,
#  'Tonight': 83,
#  'besides': 84,
#  'tepid': 85,
#  'Omelets': 86,
#  'wrong': 87,
#  'sense': 88,
#  'contained': 89,
#  'new': 90,
#  '2': 91,
#  'crowd': 92,
#  'juice..': 93,
#  'T.': 94,
#  '-': 95,
#  'unexperienced': 96,
#  'worries': 97,
#  'marrow': 98,
#  'sad': 99,
#  'flavored': 100,
#  'with': 101,
#  'loudly': 102,
#  'thumbs': 103,
#  'bank': 104,
#  'luck': 105,
#  'On': 106,
#  'constructed': 107,
#  'bites': 108,
#  'taco': 109,
#  'Pizza': 110,
#  'kiddos': 111,
#  'server': 112,
#  'chocolate': 113,
#  'BETTER': 114,
#  'Cant': 115,
#  'six': 116,
#  'solid': 117,
#  'Nobu': 118,
#  'stop': 119,
#  'Shrimp-': 120,
#  'lacking': 121,
#  'water': 122,
#  'special': 123,
#  'After': 124,
#  'Gave': 125,
#  'original': 126,
#  'Attack': 127,
#  'pancakes': 128,
#  'Overpriced': 129,
#  'Sun': 130,
#  'visit': 131,
#  'Thoroughly': 132,
#  'biscuits': 133,
#  'dude': 134,
#  'refrained': 135,
#  'deserves': 136,
#  'Come': 137,
#  'seen': 138,
#  'attention': 139,
#  'power': 140,
#  'mary': 141,
#  'bars': 142,
#  'attached': 143,
#  'away': 144,
#  'disgrace': 145,
#  'coziness': 146,
#  'during': 147,
#  'presentation': 148,
#  'when': 149,
#  'events': 150,
#  'Vegetarian': 151,
#  'takeout': 152,
#  'allergy': 153,
#  'town': 154,
#  'Ramsey': 155,
#  'event': 156,
#  'RI': 157,
#  'make': 158,
#  'under': 159,
#  'grandmother': 160,
#  'something': 161,
#  'pay': 162,
#  'beers': 163,
#  'dinner': 164,
#  'is': 165,
#  'Jamaican': 166,
#  'cheek': 167,
#  'average': 168,
#  'grill': 169,
#  'topic': 170,
#  'group': 171,
#  'Check': 172,
#  'visited': 173,
#  'sit-down': 174,
#  'WAY': 175,
#  'negligent': 176,
#  'ravoli': 177,
#  'Grill': 178,
#  'rated': 179,
#  'rich': 180,
#  'regularly': 181,
#  'struggle': 182,
#  'Buffet': 183,
#  'told': 184,
#  'Café': 185,
#  'juries': 186,
#  'dusted': 187,
#  '90': 188,
#  'Damn': 189,
#  'take': 190,
#  'remember': 191,
#  'because': 192,
#  'better': 193,
#  'gristle': 194,
#  'chewy': 195,
#  'covered': 196,
#  'bland': 197,
#  'Favorite': 198,
#  'blow': 199,
#  'plantains': 200,
#  'baklava': 201,
#  'crawfish': 202,
#  'son': 203,
#  'such': 204,
#  "'": 205,
#  'down': 206,
#  'amount': 207,
#  'beauty': 208,
#  'never': 209,
#  'asked': 210,
#  'Dos': 211,
#  'AYCE': 212,
#  'charged': 213,
#  'Perhaps': 214,
#  'toasted': 215,
#  'Scottsdale': 216,
#  'into': 217,
#  'orders': 218,
#  'overhaul': 219,
#  'here': 220,
#  'anyone': 221,
#  'rather': 222,
#  'mile': 223,
#  'red': 224,
#  'jewel': 225,
#  'places': 226,
#  'salmon': 227,
#  'Bellagio': 228,
#  'proven': 229,
#  'GREAT': 230,
#  'metro': 231,
#  'Smashburger': 232,
#  'colder': 233,
#  'bakery': 234,
#  'bagels': 235,
#  'seafood': 236,
#  'Burger': 237,
#  'Which': 238,
#  'sub-par': 239,
#  'Host': 240,
#  'disgust': 241,
#  'coupons': 242,
#  'corn': 243,
#  'break': 244,
#  'Thus': 245,
#  'hope': 246,
#  'redeeming': 247,
#  'disappointed': 248,
#  'SHOULD': 249,
#  'bruschetta': 250,
#  'me..Bunch': 251,
#  'dry': 252,
#  'Your': 253,
#  'arepas': 254,
#  'sangria': 255,
#  'sample': 256,
#  "'ve": 257,
#  'liking': 258,
#  'sucked': 259,
#  'gave': 260,
#  'services': 261,
#  'impeccable': 262,
#  'brings': 263,
#  'looking': 264,
#  'greedy': 265,
#  'spots': 266,
#  'reminds': 267,
#  '%': 268,
#  'hostess': 269,
#  'things': 270,
#  'limited': 271,
#  'industry': 272,
#  'Coming': 273,
#  'took': 274,
#  'vibe': 275,
#  'was': 276,
#  'continue': 277,
#  'arriving': 278,
#  'area/': 279,
#  'sandwich': 280,
#  'rubber': 281,
#  'Seat': 282,
#  'Paying': 283,
#  'Excalibur': 284,
#  '(': 285,
#  'hoping': 286,
#  'tribute': 287,
#  'slow': 288,
#  'Luke': 289,
#  '40min': 290,
#  'operation': 291,
#  'saffron': 292,
#  'there': 293,
#  'will': 294,
#  'stay': 295,
#  'meh': 296,
#  'your': 297,
#  'Also': 298,
#  'now': 299,
#  'across': 300,
#  'Rice': 301,
#  'time': 302,
#  'curry': 303,
#  'Voodoo': 304,
#  'cream': 305,
#  'bread': 306,
#  'Philadelphia': 307,
#  'Tasted': 308,
#  'latte': 309,
#  'self': 310,
#  'Mushroom': 311,
#  'table': 312,
#  'dressing': 313,
#  'missing': 314,
#  'grow': 315,
#  'Cod': 316,
#  'Mediterranean': 317,
#  'NYC': 318,
#  'Camelback': 319,
#  'part': 320,
#  'tastings': 321,
#  'rings': 322,
#  'uninspired': 323,
#  'beautifully': 324,
#  'Mom': 325,
#  'Filet': 326,
#  'name': 327,
#  'beautiful': 328,
#  'apple': 329,
#  'care': 330,
#  'complete': 331,
#  'nearly': 332,
#  'high': 333,
#  'try': 334,
#  'waste': 335,
#  'company': 336,
#  'dining': 337,
#  'Seafood': 338,
#  'guess': 339,
#  'most': 340,
#  'pancake': 341,
#  'Khao': 342,
#  'steak': 343,
#  'fell': 344,
#  'lovely': 345,
#  'holiday': 346,
#  'side': 347,
#  'food': 348,
#  'BARE': 349,
#  'Con': 350,
#  'tummy': 351,
#  'funny': 352,
#  'understand': 353,
#  'couple': 354,
#  'summarize': 355,
#  'No': 356,
#  'between': 357,
#  'bamboo': 358,
#  'pho': 359,
#  'honest': 360,
#  'rude': 361,
#  'welcome': 362,
#  'genuinely': 363,
#  'tuna': 364,
#  'Strike': 365,
#  'May': 366,
#  'thanks': 367,
#  'rate': 368,
#  'Heart': 369,
#  'late': 370,
#  'cake': 371,
#  'accordingly': 372,
#  'else': 373,
#  'larger': 374,
#  'handling': 375,
#  'mixed': 376,
#  'HAPPENED': 377,
#  'gooodd': 378,
#  'thru': 379,
#  'due': 380,
#  'acknowledged': 381,
#  'plastic': 382,
#  'smoothies': 383,
#  'party': 384,
#  'Really': 385,
#  'Now': 386,
#  'butter': 387,
#  'fairly': 388,
#  'Reasonably': 389,
#  'shocked': 390,
#  'somehow': 391,
#  'Elk': 392,
#  'calligraphy': 393,
#  'experienced': 394,
#  'employees': 395,
#  'Wife': 396,
#  'same': 397,
#  '1979': 398,
#  'lady': 399,
#  'waiting': 400,
#  'char': 401,
#  'helped': 402,
#  'Cibo': 403,
#  'Standard': 404,
#  'Egg': 405,
#  'ground': 406,
#  'over-priced': 407,
#  'Denny': 408,
#  'customer': 409,
#  'vegetarian': 410,
#  'Google': 411,
#  'customize': 412,
#  'what': 413,
#  'revisiting': 414,
#  '6': 415,
#  'satisfied': 416,
#  'wontons': 417,
#  'treat': 418,
#  'mesquite': 419,
#  'officially': 420,
#  'whenever': 421,
#  'absolutley': 422,
#  'baby': 423,
#  'feel': 424,
#  'mean': 425,
#  'drawing': 426,
#  'Stars': 427,
#  'poorly': 428,
#  'thinking': 429,
#  'interesting': 430,
#  'to': 431,
#  'buying': 432,
#  'typical': 433,
#  'definately': 434,
#  'boys': 435,
#  'douchey': 436,
#  'worker': 437,
#  'terrific': 438,
#  'vinaigrette': 439,
#  'Interesting': 440,
#  'absolutely': 441,
#  'killer': 442,
#  'look': 443,
#  'Some': 444,
#  'count': 445,
#  'we': 446,
#  'tartare': 447,
#  'sliced': 448,
#  'arrives': 449,
#  'efficient': 450,
#  'truly': 451,
#  '-My': 452,
#  'thing': 453,
#  'APPETIZERS': 454,
#  'crazy': 455,
#  'come': 456,
#  'reasons': 457,
#  'slices': 458,
#  'anymore': 459,
#  'pizza': 460,
#  'Lox': 461,
#  'wait': 462,
#  'enjoyed': 463,
#  'appalling': 464,
#  'highlight': 465,
#  'imaginative': 466,
#  'months': 467,
#  'devine': 468,
#  'Roll': 469,
#  'fish': 470,
#  'enough..': 471,
#  '2007': 472,
#  'Mmmm': 473,
#  'Extremely': 474,
#  'ratio': 475,
#  'Frozen': 476,
#  ',': 477,
#  'single': 478,
#  'Japanese': 479,
#  'movies': 480,
#  'Rock': 481,
#  'Oh': 482,
#  'fails': 483,
#  'ethic': 484,
#  'Han': 485,
#  'impressive': 486,
#  'yum': 487,
#  'lover': 488,
#  'opened': 489,
#  'palate': 490,
#  'Bay': 491,
#  'happy': 492,
#  'become': 493,
#  'sexy': 494,
#  'anything': 495,
#  'brother': 496,
#  'disgusting': 497,
#  'read': 498,
#  'pneumatic': 499,
#  'meals': 500,
#  'stars': 501,
#  'hearts': 502,
#  'kid': 503,
#  'toro': 504,
#  'dont': 505,
#  'requested': 506,
#  'dedicated': 507,
#  'REAL': 508,
#  'Magic': 509,
#  'Perfect': 510,
#  'replenished': 511,
#  '..ohhh': 512,
#  'until': 513,
#  'awful': 514,
#  'number': 515,
#  'i': 516,
#  'playing': 517,
#  'stinks': 518,
#  'Ironman': 519,
#  'Dessert': 520,
#  'piano': 521,
#  'star': 522,
#  'cocktail': 523,
#  'Madison': 524,
#  'tongue': 525,
#  'soggy': 526,
#  'crowds': 527,
#  '...': 528,
#  '8': 529,
#  'Then': 530,
#  'watered': 531,
#  'boxes': 532,
#  'ingredients': 533,
#  'live': 534,
#  'CONCLUSION': 535,
#  'Ambience': 536,
#  'sound': 537,
#  'Lobster': 538,
#  'Each': 539,
#  'cramming': 540,
#  'girlfriend': 541,
#  'blandest': 542,
#  'venture': 543,
#  '..went': 544,
#  'station': 545,
#  'surprised': 546,
#  'non-customer': 547,
#  'seating': 548,
#  'door': 549,
#  'hungry': 550,
#  '.off': 551,
#  'privileged': 552,
#  'lost': 553,
#  'crisp': 554,
#  'NOT': 555,
#  'recommendation': 556,
#  'Worst': 557,
#  'condiment': 558,
#  'dime': 559,
#  'above': 560,
#  'promptly': 561,
#  'turn': 562,
#  'Plus': 563,
#  'offered': 564,
#  'perfectly': 565,
#  'accident': 566,
#  'hospitality': 567,
#  'known': 568,
#  'avocado': 569,
#  'puréed': 570,
#  'legs': 571,
#  'lacked': 572,
#  'ago': 573,
#  'godfathers': 574,
#  'Bad': 575,
#  'Went': 576,
#  'extra': 577,
#  'lil': 578,
#  'hardest': 579,
#  'untoasted': 580,
#  'mein': 581,
#  'venturing': 582,
#  'empty': 583,
#  'Cooked': 584,
#  'hard': 585,
#  'flat': 586,
#  'cause': 587,
#  'say': 588,
#  'room': 589,
#  'VERY': 590,
#  'cakes': 591,
#  'she': 592,
#  'pucks': 593,
#  'inflate': 594,
#  'space': 595,
#  'monster': 596,
#  'degree': 597,
#  'dates': 598,
#  'charcoal': 599,
#  'fair': 600,
#  'grease': 601,
#  'pizzas': 602,
#  'Pricing': 603,
#  'sweet': 604,
#  'correct': 605,
#  'imagined': 606,
#  'hooked': 607,
#  'cow': 608,
#  'word': 609,
#  'Spend': 610,
#  'literally': 611,
#  'mess': 612,
#  'delicioso': 613,
#  'idea': 614,
#  'To': 615,
#  'guy': 616,
#  'awkwardly': 617,
#  'top': 618,
#  'hate': 619,
#  'so': 620,
#  'creamy': 621,
#  'relleno': 622,
#  'opposed': 623,
#  'hair': 624,
#  'satifying': 625,
#  'people': 626,
#  'nicest': 627,
#  'give': 628,
#  'almost': 629,
#  'words': 630,
#  'Point': 631,
#  'hot': 632,
#  '?': 633,
#  'selections': 634,
#  'cut': 635,
#  'wrapped': 636,
#  'favor': 637,
#  'obviously': 638,
#  'ever': 639,
#  'accomodate': 640,
#  'profiterole': 641,
#  'Lastly': 642,
#  'reviewing..': 643,
#  'are': 644,
#  'traditional': 645,
#  'waitresses': 646,
#  'hella': 647,
#  'every': 648,
#  'saying': 649,
#  'tell': 650,
#  'Those': 651,
#  'reason': 652,
#  'ripped': 653,
#  'qualified': 654,
#  'Give': 655,
#  'Gourmet': 656,
#  'eating': 657,
#  'brought': 658,
#  'green': 659,
#  'WEAK': 660,
#  'hours': 661,
#  'Rick': 662,
#  'boring': 663,
#  'vacant': 664,
#  'prefer': 665,
#  'rapidly': 666,
#  'though': 667,
#  'sat': 668,
#  'simply': 669,
#  'elegantly': 670,
#  'succulent': 671,
#  'golden-crispy': 672,
#  'rest': 673,
#  'Delicious': 674,
#  'mention': 675,
#  'thin': 676,
#  'carbs': 677,
#  'rice': 678,
#  'But': 679,
#  'the': 680,
#  'Our': 681,
#  'disaster': 682,
#  'seated': 683,
#  'INCONSIDERATE': 684,
#  'groups': 685,
#  'concept': 686,
#  'Veggitarian': 687,
#  'putting': 688,
#  'suggest': 689,
#  'rare': 690,
#  'judging': 691,
#  'hopes': 692,
#  'glass': 693,
#  'Always': 694,
#  'disagree': 695,
#  'class': 696,
#  'clean': 697,
#  'all': 698,
#  'working/eating': 699,
#  'cart': 700,
#  'Hot': 701,
#  'exceeding': 702,
#  'Subway': 703,
#  'enjoyable': 704,
#  'coconut': 705,
#  'without': 706,
#  'OMG': 707,
#  'oil': 708,
#  'old': 709,
#  'walls': 710,
#  'chicken': 711,
#  'Ha': 712,
#  'Crema': 713,
#  'Greek': 714,
#  '17': 715,
#  'correction': 716,
#  'BITCHES': 717,
#  'restaraunt': 718,
#  'watched': 719,
#  'once': 720,
#  'how': 721,
#  'Be': 722,
#  'Nicest': 723,
#  ')': 724,
#  'transcendant': 725,
#  'Baseball': 726,
#  'bartender': 727,
#  'like': 728,
#  'tailored': 729,
#  'classic': 730,
#  'Four': 731,
#  'Much': 732,
#  'poured': 733,
#  'letting': 734,
#  'parents': 735,
#  'hand': 736,
#  'tasty': 737,
#  'fella': 738,
#  'truffle': 739,
#  'MANAGEMENT': 740,
#  'MGM': 741,
#  'recent': 742,
#  'Green': 743,
#  'must-stop': 744,
#  'an': 745,
#  'finish': 746,
#  'especially': 747,
#  'him': 748,
#  'Sprouts': 749,
#  '4': 750,
#  'For': 751,
#  'eyes': 752,
#  'strange': 753,
#  '10': 754,
#  '.way': 755,
#  'Sour': 756,
#  'Never': 757,
#  'first': 758,
#  'Cape': 759,
#  'stir': 760,
#  'outta': 761,
#  'Wienerschnitzel': 762,
#  'strawberry': 763,
#  'greens': 764,
#  'struck': 765,
#  'quit': 766,
#  'readers': 767,
#  'Third': 768,
#  'assure': 769,
#  'Chinese': 770,
#  'head': 771,
#  '45': 772,
#  'eaten': 773,
#  'Service-check': 774,
#  'Sauce': 775,
#  'duck': 776,
#  'Everything': 777,
#  'before': 778,
#  'Large': 779,
#  'register': 780,
#  'speedy': 781,
#  'decorated': 782,
#  'weekly': 783,
#  'small': 784,
#  'bother': 785,
#  'unbelievable': 786,
#  'although': 787,
#  'dipping': 788,
#  'chains': 789,
#  'right': 790,
#  'showed': 791,
#  'refill': 792,
#  'wedges': 793,
#  'AN': 794,
#  'list': 795,
#  'BEST': 796,
#  'Level': 797,
#  'San': 798,
#  'menus': 799,
#  'suggestions': 800,
#  'wildly': 801,
#  'nutshell': 802,
#  'min': 803,
#  'Do': 804,
#  'texture': 805,
#  'review': 806,
#  'My': 807,
#  'meats': 808,
#  'Thai': 809,
#  'Great': 810,
#  'pop': 811,
#  'put': 812,
#  'inch': 813,
#  'descriptions': 814,
#  'few': 815,
#  '3/4ths': 816,
#  'hits': 817,
#  'pork': 818,
#  'less': 819,
#  'Baba': 820,
#  'apparently': 821,
#  "'ll": 822,
#  'vomited': 823,
#  'evening': 824,
#  'Def': 825,
#  'Ninja': 826,
#  'disgraceful': 827,
#  'that': 828,
#  'next': 829,
#  'Bouchon': 830,
#  'daily': 831,
#  'believe': 832,
#  'day': 833,
#  'it': 834,
#  'crusty': 835,
#  'waitress': 836,
#  'thrilled': 837,
#  'Avoid': 838,
#  'wife': 839,
#  'quantity': 840,
#  'does': 841,
#  'would': 842,
#  'twice': 843,
#  'flavors': 844,
#  'doubt': 845,
#  'minutes': 846,
#  'anticipated': 847,
#  'serves': 848,
#  'oven': 849,
#  'RUDE': 850,
#  'mistake': 851,
#  'burger': 852,
#  'Frenchman': 853,
#  'menu/': 854,
#  'together': 855,
#  'or': 856,
#  'Similarly': 857,
#  'glad': 858,
#  'Bisque': 859,
#  'maintaining': 860,
#  'par': 861,
#  'everyone': 862,
#  'being': 863,
#  'stomach': 864,
#  'lukewarm': 865,
#  'oysters': 866,
#  'item': 867,
#  'eat': 868,
#  'hottest': 869,
#  'WAAAAAAyyyyyyyyyy': 870,
#  '$': 871,
#  'watch': 872,
#  'than': 873,
#  'its': 874,
#  "''": 875,
#  'waiter': 876,
#  'find': 877,
#  'still': 878,
#  'double': 879,
#  'gone': 880,
#  'smaller': 881,
#  'ache': 882,
#  'usual': 883,
#  'Steiners': 884,
#  'BARGAIN': 885,
#  'binge': 886,
#  'doughy': 887,
#  'decent': 888,
#  'Kind': 889,
#  'extraordinary': 890,
#  'they': 891,
#  'amazing': 892,
#  'Unfortunately': 893,
#  'vegetables': 894,
#  "'s": 895,
#  'profound': 896,
#  'friends': 897,
#  'flavourful': 898,
#  'meatloaf': 899,
#  'pace': 900,
#  'cashew': 901,
#  'meal': 902,
#  'recommending': 903,
#  'positive': 904,
#  'blown': 905,
#  'talk': 906,
#  'Maine': 907,
#  'family': 908,
#  'one': 909,
#  'crumby': 910,
#  'tough': 911,
#  'worth': 912,
#  'Delight': 913,
#  'deuchebaggery': 914,
#  'Las': 915,
#  'handled': 916,
#  'begin': 917,
#  'Sunday': 918,
#  'You': 919,
#  'return': 920,
#  'tiramisu': 921,
#  'who': 922,
#  'shopping': 923,
#  'BBQ': 924,
#  'margaritas': 925,
#  'uploaded': 926,
#  'others': 927,
#  'no': 928,
#  'providing': 929,
#  'rib': 930,
#  'capers': 931,
#  'dollars': 932,
#  'really': 933,
#  'beat': 934,
#  'stood': 935,
#  'employee': 936,
#  'yucky': 937,
#  'Place': 938,
#  'handed': 939,
#  'recommended': 940,
#  'teeth': 941,
#  'law': 942,
#  'fav': 943,
#  'silently': 944,
#  'instantly': 945,
#  'wagyu': 946,
#  'whole': 947,
#  'andddd': 948,
#  'lack': 949,
#  'simple': 950,
#  'each': 951,
#  'underwhelming': 952,
#  'crust': 953,
#  'lightly': 954,
#  'subpar': 955,
#  'inexpensive': 956,
#  'FLY': 957,
#  'What': 958,
#  'whatsoever': 959,
#  '.the': 960,
#  'DELICIOUS': 961,
#  'array': 962,
#  'decor': 963,
#  'relocated': 964,
#  'likes': 965,
#  'gyros': 966,
#  'Mango': 967,
#  'over': 968,
#  'dried': 969,
#  'Of': 970,
#  'Costco': 971,
#  'warnings': 972,
#  'paid': 973,
#  'changing': 974,
#  'Sadly': 975,
#  'chai': 976,
#  'guests': 977,
#  'poor': 978,
#  'ended': 979,
#  'contain': 980,
#  'smelled': 981,
#  'cafe': 982,
#  'Generous': 983,
#  'They': 984,
#  'Area': 985,
#  'brisket': 986,
#  'restaurant': 987,
#  'lovers': 988,
#  'Restaurant': 989,
#  'help': 990,
#  'goat': 991,
#  '1.5lb': 992,
#  'platter': 993,
#  'smells': 994,
#  'delicate': 995,
#  'Jenni': 996,
#  'black': 997,
#  'fondue': 998,
#  'bellies': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'downright',
#  1: 'my',
#  2: 'can',
#  3: 'incredibly',
#  4: 'treated',
#  5: 'Gold',
#  6: 'beer',
#  7: 'hurry',
#  8: 'wide',
#  9: 'Same',
#  10: 'paper',
#  11: 'myself',
#  12: 'somethat',
#  13: 'spot',
#  14: 'mains',
#  15: 'Furthermore',
#  16: 'hilarious',
#  17: 'best',
#  18: 'saving',
#  19: 'definitely',
#  20: 'legit',
#  21: 'fabulous',
#  22: 'mouth',
#  23: 'warm',
#  24: 'Risotto',
#  25: 'been-stepped-in-and-tracked-everywhere',
#  26: 'desserts',
#  27: 'free',
#  28: 'deliciously',
#  29: 'box',
#  30: '1',
#  31: 'happened',
#  32: 'Casino',
#  33: 'salads',
#  34: 'complain',
#  35: 'bartenders',
#  36: 'plethora',
#  37: 'bigger',
#  38: 'Things',
#  39: 'getting',
#  40: 'been',
#  41: 'Boy',
#  42: 'owners',
#  43: 'reviewer',
#  44: 'Nan',
#  45: '11.99',
#  46: 'tea',
#  47: 'do',
#  48: 'life',
#  49: 'drunk',
#  50: 'pictures',
#  51: 'We',
#  52: 'tacos',
#  53: 'Bloody',
#  54: 'specials',
#  55: 'least',
#  56: 'impressed',
#  57: 'tragedy',
#  58: 'Maria',
#  59: 'freaking',
#  60: 'handmade',
#  61: 'Nothing',
#  62: '.THE',
#  63: 'Gordon',
#  64: 'Try',
#  65: 'were',
#  66: 'beans',
#  67: 'focused',
#  68: 'our',
#  69: 'blanket',
#  70: 'Update',
#  71: 'mouths',
#  72: 'liked',
#  73: 'elsewhere',
#  74: 'combination',
#  75: 'coffee',
#  76: 'companions',
#  77: 'compliments',
#  78: 'mmmm',
#  79: 'his',
#  80: 'ok',
#  81: 'fail',
#  82: 'someone',
#  83: 'Tonight',
#  84: 'besides',
#  85: 'tepid',
#  86: 'Omelets',
#  87: 'wrong',
#  88: 'sense',
#  89: 'contained',
#  90: 'new',
#  91: '2',
#  92: 'crowd',
#  93: 'juice..',
#  94: 'T.',
#  95: '-',
#  96: 'unexperienced',
#  97: 'worries',
#  98: 'marrow',
#  99: 'sad',
#  100: 'flavored',
#  101: 'with',
#  102: 'loudly',
#  103: 'thumbs',
#  104: 'bank',
#  105: 'luck',
#  106: 'On',
#  107: 'constructed',
#  108: 'bites',
#  109: 'taco',
#  110: 'Pizza',
#  111: 'kiddos',
#  112: 'server',
#  113: 'chocolate',
#  114: 'BETTER',
#  115: 'Cant',
#  116: 'six',
#  117: 'solid',
#  118: 'Nobu',
#  119: 'stop',
#  120: 'Shrimp-',
#  121: 'lacking',
#  122: 'water',
#  123: 'special',
#  124: 'After',
#  125: 'Gave',
#  126: 'original',
#  127: 'Attack',
#  128: 'pancakes',
#  129: 'Overpriced',
#  130: 'Sun',
#  131: 'visit',
#  132: 'Thoroughly',
#  133: 'biscuits',
#  134: 'dude',
#  135: 'refrained',
#  136: 'deserves',
#  137: 'Come',
#  138: 'seen',
#  139: 'attention',
#  140: 'power',
#  141: 'mary',
#  142: 'bars',
#  143: 'attached',
#  144: 'away',
#  145: 'disgrace',
#  146: 'coziness',
#  147: 'during',
#  148: 'presentation',
#  149: 'when',
#  150: 'events',
#  151: 'Vegetarian',
#  152: 'takeout',
#  153: 'allergy',
#  154: 'town',
#  155: 'Ramsey',
#  156: 'event',
#  157: 'RI',
#  158: 'make',
#  159: 'under',
#  160: 'grandmother',
#  161: 'something',
#  162: 'pay',
#  163: 'beers',
#  164: 'dinner',
#  165: 'is',
#  166: 'Jamaican',
#  167: 'cheek',
#  168: 'average',
#  169: 'grill',
#  170: 'topic',
#  171: 'group',
#  172: 'Check',
#  173: 'visited',
#  174: 'sit-down',
#  175: 'WAY',
#  176: 'negligent',
#  177: 'ravoli',
#  178: 'Grill',
#  179: 'rated',
#  180: 'rich',
#  181: 'regularly',
#  182: 'struggle',
#  183: 'Buffet',
#  184: 'told',
#  185: 'Café',
#  186: 'juries',
#  187: 'dusted',
#  188: '90',
#  189: 'Damn',
#  190: 'take',
#  191: 'remember',
#  192: 'because',
#  193: 'better',
#  194: 'gristle',
#  195: 'chewy',
#  196: 'covered',
#  197: 'bland',
#  198: 'Favorite',
#  199: 'blow',
#  200: 'plantains',
#  201: 'baklava',
#  202: 'crawfish',
#  203: 'son',
#  204: 'such',
#  205: "'",
#  206: 'down',
#  207: 'amount',
#  208: 'beauty',
#  209: 'never',
#  210: 'asked',
#  211: 'Dos',
#  212: 'AYCE',
#  213: 'charged',
#  214: 'Perhaps',
#  215: 'toasted',
#  216: 'Scottsdale',
#  217: 'into',
#  218: 'orders',
#  219: 'overhaul',
#  220: 'here',
#  221: 'anyone',
#  222: 'rather',
#  223: 'mile',
#  224: 'red',
#  225: 'jewel',
#  226: 'places',
#  227: 'salmon',
#  228: 'Bellagio',
#  229: 'proven',
#  230: 'GREAT',
#  231: 'metro',
#  232: 'Smashburger',
#  233: 'colder',
#  234: 'bakery',
#  235: 'bagels',
#  236: 'seafood',
#  237: 'Burger',
#  238: 'Which',
#  239: 'sub-par',
#  240: 'Host',
#  241: 'disgust',
#  242: 'coupons',
#  243: 'corn',
#  244: 'break',
#  245: 'Thus',
#  246: 'hope',
#  247: 'redeeming',
#  248: 'disappointed',
#  249: 'SHOULD',
#  250: 'bruschetta',
#  251: 'me..Bunch',
#  252: 'dry',
#  253: 'Your',
#  254: 'arepas',
#  255: 'sangria',
#  256: 'sample',
#  257: "'ve",
#  258: 'liking',
#  259: 'sucked',
#  260: 'gave',
#  261: 'services',
#  262: 'impeccable',
#  263: 'brings',
#  264: 'looking',
#  265: 'greedy',
#  266: 'spots',
#  267: 'reminds',
#  268: '%',
#  269: 'hostess',
#  270: 'things',
#  271: 'limited',
#  272: 'industry',
#  273: 'Coming',
#  274: 'took',
#  275: 'vibe',
#  276: 'was',
#  277: 'continue',
#  278: 'arriving',
#  279: 'area/',
#  280: 'sandwich',
#  281: 'rubber',
#  282: 'Seat',
#  283: 'Paying',
#  284: 'Excalibur',
#  285: '(',
#  286: 'hoping',
#  287: 'tribute',
#  288: 'slow',
#  289: 'Luke',
#  290: '40min',
#  291: 'operation',
#  292: 'saffron',
#  293: 'there',
#  294: 'will',
#  295: 'stay',
#  296: 'meh',
#  297: 'your',
#  298: 'Also',
#  299: 'now',
#  300: 'across',
#  301: 'Rice',
#  302: 'time',
#  303: 'curry',
#  304: 'Voodoo',
#  305: 'cream',
#  306: 'bread',
#  307: 'Philadelphia',
#  308: 'Tasted',
#  309: 'latte',
#  310: 'self',
#  311: 'Mushroom',
#  312: 'table',
#  313: 'dressing',
#  314: 'missing',
#  315: 'grow',
#  316: 'Cod',
#  317: 'Mediterranean',
#  318: 'NYC',
#  319: 'Camelback',
#  320: 'part',
#  321: 'tastings',
#  322: 'rings',
#  323: 'uninspired',
#  324: 'beautifully',
#  325: 'Mom',
#  326: 'Filet',
#  327: 'name',
#  328: 'beautiful',
#  329: 'apple',
#  330: 'care',
#  331: 'complete',
#  332: 'nearly',
#  333: 'high',
#  334: 'try',
#  335: 'waste',
#  336: 'company',
#  337: 'dining',
#  338: 'Seafood',
#  339: 'guess',
#  340: 'most',
#  341: 'pancake',
#  342: 'Khao',
#  343: 'steak',
#  344: 'fell',
#  345: 'lovely',
#  346: 'holiday',
#  347: 'side',
#  348: 'food',
#  349: 'BARE',
#  350: 'Con',
#  351: 'tummy',
#  352: 'funny',
#  353: 'understand',
#  354: 'couple',
#  355: 'summarize',
#  356: 'No',
#  357: 'between',
#  358: 'bamboo',
#  359: 'pho',
#  360: 'honest',
#  361: 'rude',
#  362: 'welcome',
#  363: 'genuinely',
#  364: 'tuna',
#  365: 'Strike',
#  366: 'May',
#  367: 'thanks',
#  368: 'rate',
#  369: 'Heart',
#  370: 'late',
#  371: 'cake',
#  372: 'accordingly',
#  373: 'else',
#  374: 'larger',
#  375: 'handling',
#  376: 'mixed',
#  377: 'HAPPENED',
#  378: 'gooodd',
#  379: 'thru',
#  380: 'due',
#  381: 'acknowledged',
#  382: 'plastic',
#  383: 'smoothies',
#  384: 'party',
#  385: 'Really',
#  386: 'Now',
#  387: 'butter',
#  388: 'fairly',
#  389: 'Reasonably',
#  390: 'shocked',
#  391: 'somehow',
#  392: 'Elk',
#  393: 'calligraphy',
#  394: 'experienced',
#  395: 'employees',
#  396: 'Wife',
#  397: 'same',
#  398: '1979',
#  399: 'lady',
#  400: 'waiting',
#  401: 'char',
#  402: 'helped',
#  403: 'Cibo',
#  404: 'Standard',
#  405: 'Egg',
#  406: 'ground',
#  407: 'over-priced',
#  408: 'Denny',
#  409: 'customer',
#  410: 'vegetarian',
#  411: 'Google',
#  412: 'customize',
#  413: 'what',
#  414: 'revisiting',
#  415: '6',
#  416: 'satisfied',
#  417: 'wontons',
#  418: 'treat',
#  419: 'mesquite',
#  420: 'officially',
#  421: 'whenever',
#  422: 'absolutley',
#  423: 'baby',
#  424: 'feel',
#  425: 'mean',
#  426: 'drawing',
#  427: 'Stars',
#  428: 'poorly',
#  429: 'thinking',
#  430: 'interesting',
#  431: 'to',
#  432: 'buying',
#  433: 'typical',
#  434: 'definately',
#  435: 'boys',
#  436: 'douchey',
#  437: 'worker',
#  438: 'terrific',
#  439: 'vinaigrette',
#  440: 'Interesting',
#  441: 'absolutely',
#  442: 'killer',
#  443: 'look',
#  444: 'Some',
#  445: 'count',
#  446: 'we',
#  447: 'tartare',
#  448: 'sliced',
#  449: 'arrives',
#  450: 'efficient',
#  451: 'truly',
#  452: '-My',
#  453: 'thing',
#  454: 'APPETIZERS',
#  455: 'crazy',
#  456: 'come',
#  457: 'reasons',
#  458: 'slices',
#  459: 'anymore',
#  460: 'pizza',
#  461: 'Lox',
#  462: 'wait',
#  463: 'enjoyed',
#  464: 'appalling',
#  465: 'highlight',
#  466: 'imaginative',
#  467: 'months',
#  468: 'devine',
#  469: 'Roll',
#  470: 'fish',
#  471: 'enough..',
#  472: '2007',
#  473: 'Mmmm',
#  474: 'Extremely',
#  475: 'ratio',
#  476: 'Frozen',
#  477: ',',
#  478: 'single',
#  479: 'Japanese',
#  480: 'movies',
#  481: 'Rock',
#  482: 'Oh',
#  483: 'fails',
#  484: 'ethic',
#  485: 'Han',
#  486: 'impressive',
#  487: 'yum',
#  488: 'lover',
#  489: 'opened',
#  490: 'palate',
#  491: 'Bay',
#  492: 'happy',
#  493: 'become',
#  494: 'sexy',
#  495: 'anything',
#  496: 'brother',
#  497: 'disgusting',
#  498: 'read',
#  499: 'pneumatic',
#  500: 'meals',
#  501: 'stars',
#  502: 'hearts',
#  503: 'kid',
#  504: 'toro',
#  505: 'dont',
#  506: 'requested',
#  507: 'dedicated',
#  508: 'REAL',
#  509: 'Magic',
#  510: 'Perfect',
#  511: 'replenished',
#  512: '..ohhh',
#  513: 'until',
#  514: 'awful',
#  515: 'number',
#  516: 'i',
#  517: 'playing',
#  518: 'stinks',
#  519: 'Ironman',
#  520: 'Dessert',
#  521: 'piano',
#  522: 'star',
#  523: 'cocktail',
#  524: 'Madison',
#  525: 'tongue',
#  526: 'soggy',
#  527: 'crowds',
#  528: '...',
#  529: '8',
#  530: 'Then',
#  531: 'watered',
#  532: 'boxes',
#  533: 'ingredients',
#  534: 'live',
#  535: 'CONCLUSION',
#  536: 'Ambience',
#  537: 'sound',
#  538: 'Lobster',
#  539: 'Each',
#  540: 'cramming',
#  541: 'girlfriend',
#  542: 'blandest',
#  543: 'venture',
#  544: '..went',
#  545: 'station',
#  546: 'surprised',
#  547: 'non-customer',
#  548: 'seating',
#  549: 'door',
#  550: 'hungry',
#  551: '.off',
#  552: 'privileged',
#  553: 'lost',
#  554: 'crisp',
#  555: 'NOT',
#  556: 'recommendation',
#  557: 'Worst',
#  558: 'condiment',
#  559: 'dime',
#  560: 'above',
#  561: 'promptly',
#  562: 'turn',
#  563: 'Plus',
#  564: 'offered',
#  565: 'perfectly',
#  566: 'accident',
#  567: 'hospitality',
#  568: 'known',
#  569: 'avocado',
#  570: 'puréed',
#  571: 'legs',
#  572: 'lacked',
#  573: 'ago',
#  574: 'godfathers',
#  575: 'Bad',
#  576: 'Went',
#  577: 'extra',
#  578: 'lil',
#  579: 'hardest',
#  580: 'untoasted',
#  581: 'mein',
#  582: 'venturing',
#  583: 'empty',
#  584: 'Cooked',
#  585: 'hard',
#  586: 'flat',
#  587: 'cause',
#  588: 'say',
#  589: 'room',
#  590: 'VERY',
#  591: 'cakes',
#  592: 'she',
#  593: 'pucks',
#  594: 'inflate',
#  595: 'space',
#  596: 'monster',
#  597: 'degree',
#  598: 'dates',
#  599: 'charcoal',
#  600: 'fair',
#  601: 'grease',
#  602: 'pizzas',
#  603: 'Pricing',
#  604: 'sweet',
#  605: 'correct',
#  606: 'imagined',
#  607: 'hooked',
#  608: 'cow',
#  609: 'word',
#  610: 'Spend',
#  611: 'literally',
#  612: 'mess',
#  613: 'delicioso',
#  614: 'idea',
#  615: 'To',
#  616: 'guy',
#  617: 'awkwardly',
#  618: 'top',
#  619: 'hate',
#  620: 'so',
#  621: 'creamy',
#  622: 'relleno',
#  623: 'opposed',
#  624: 'hair',
#  625: 'satifying',
#  626: 'people',
#  627: 'nicest',
#  628: 'give',
#  629: 'almost',
#  630: 'words',
#  631: 'Point',
#  632: 'hot',
#  633: '?',
#  634: 'selections',
#  635: 'cut',
#  636: 'wrapped',
#  637: 'favor',
#  638: 'obviously',
#  639: 'ever',
#  640: 'accomodate',
#  641: 'profiterole',
#  642: 'Lastly',
#  643: 'reviewing..',
#  644: 'are',
#  645: 'traditional',
#  646: 'waitresses',
#  647: 'hella',
#  648: 'every',
#  649: 'saying',
#  650: 'tell',
#  651: 'Those',
#  652: 'reason',
#  653: 'ripped',
#  654: 'qualified',
#  655: 'Give',
#  656: 'Gourmet',
#  657: 'eating',
#  658: 'brought',
#  659: 'green',
#  660: 'WEAK',
#  661: 'hours',
#  662: 'Rick',
#  663: 'boring',
#  664: 'vacant',
#  665: 'prefer',
#  666: 'rapidly',
#  667: 'though',
#  668: 'sat',
#  669: 'simply',
#  670: 'elegantly',
#  671: 'succulent',
#  672: 'golden-crispy',
#  673: 'rest',
#  674: 'Delicious',
#  675: 'mention',
#  676: 'thin',
#  677: 'carbs',
#  678: 'rice',
#  679: 'But',
#  680: 'the',
#  681: 'Our',
#  682: 'disaster',
#  683: 'seated',
#  684: 'INCONSIDERATE',
#  685: 'groups',
#  686: 'concept',
#  687: 'Veggitarian',
#  688: 'putting',
#  689: 'suggest',
#  690: 'rare',
#  691: 'judging',
#  692: 'hopes',
#  693: 'glass',
#  694: 'Always',
#  695: 'disagree',
#  696: 'class',
#  697: 'clean',
#  698: 'all',
#  699: 'working/eating',
#  700: 'cart',
#  701: 'Hot',
#  702: 'exceeding',
#  703: 'Subway',
#  704: 'enjoyable',
#  705: 'coconut',
#  706: 'without',
#  707: 'OMG',
#  708: 'oil',
#  709: 'old',
#  710: 'walls',
#  711: 'chicken',
#  712: 'Ha',
#  713: 'Crema',
#  714: 'Greek',
#  715: '17',
#  716: 'correction',
#  717: 'BITCHES',
#  718: 'restaraunt',
#  719: 'watched',
#  720: 'once',
#  721: 'how',
#  722: 'Be',
#  723: 'Nicest',
#  724: ')',
#  725: 'transcendant',
#  726: 'Baseball',
#  727: 'bartender',
#  728: 'like',
#  729: 'tailored',
#  730: 'classic',
#  731: 'Four',
#  732: 'Much',
#  733: 'poured',
#  734: 'letting',
#  735: 'parents',
#  736: 'hand',
#  737: 'tasty',
#  738: 'fella',
#  739: 'truffle',
#  740: 'MANAGEMENT',
#  741: 'MGM',
#  742: 'recent',
#  743: 'Green',
#  744: 'must-stop',
#  745: 'an',
#  746: 'finish',
#  747: 'especially',
#  748: 'him',
#  749: 'Sprouts',
#  750: '4',
#  751: 'For',
#  752: 'eyes',
#  753: 'strange',
#  754: '10',
#  755: '.way',
#  756: 'Sour',
#  757: 'Never',
#  758: 'first',
#  759: 'Cape',
#  760: 'stir',
#  761: 'outta',
#  762: 'Wienerschnitzel',
#  763: 'strawberry',
#  764: 'greens',
#  765: 'struck',
#  766: 'quit',
#  767: 'readers',
#  768: 'Third',
#  769: 'assure',
#  770: 'Chinese',
#  771: 'head',
#  772: '45',
#  773: 'eaten',
#  774: 'Service-check',
#  775: 'Sauce',
#  776: 'duck',
#  777: 'Everything',
#  778: 'before',
#  779: 'Large',
#  780: 'register',
#  781: 'speedy',
#  782: 'decorated',
#  783: 'weekly',
#  784: 'small',
#  785: 'bother',
#  786: 'unbelievable',
#  787: 'although',
#  788: 'dipping',
#  789: 'chains',
#  790: 'right',
#  791: 'showed',
#  792: 'refill',
#  793: 'wedges',
#  794: 'AN',
#  795: 'list',
#  796: 'BEST',
#  797: 'Level',
#  798: 'San',
#  799: 'menus',
#  800: 'suggestions',
#  801: 'wildly',
#  802: 'nutshell',
#  803: 'min',
#  804: 'Do',
#  805: 'texture',
#  806: 'review',
#  807: 'My',
#  808: 'meats',
#  809: 'Thai',
#  810: 'Great',
#  811: 'pop',
#  812: 'put',
#  813: 'inch',
#  814: 'descriptions',
#  815: 'few',
#  816: '3/4ths',
#  817: 'hits',
#  818: 'pork',
#  819: 'less',
#  820: 'Baba',
#  821: 'apparently',
#  822: "'ll",
#  823: 'vomited',
#  824: 'evening',
#  825: 'Def',
#  826: 'Ninja',
#  827: 'disgraceful',
#  828: 'that',
#  829: 'next',
#  830: 'Bouchon',
#  831: 'daily',
#  832: 'believe',
#  833: 'day',
#  834: 'it',
#  835: 'crusty',
#  836: 'waitress',
#  837: 'thrilled',
#  838: 'Avoid',
#  839: 'wife',
#  840: 'quantity',
#  841: 'does',
#  842: 'would',
#  843: 'twice',
#  844: 'flavors',
#  845: 'doubt',
#  846: 'minutes',
#  847: 'anticipated',
#  848: 'serves',
#  849: 'oven',
#  850: 'RUDE',
#  851: 'mistake',
#  852: 'burger',
#  853: 'Frenchman',
#  854: 'menu/',
#  855: 'together',
#  856: 'or',
#  857: 'Similarly',
#  858: 'glad',
#  859: 'Bisque',
#  860: 'maintaining',
#  861: 'par',
#  862: 'everyone',
#  863: 'being',
#  864: 'stomach',
#  865: 'lukewarm',
#  866: 'oysters',
#  867: 'item',
#  868: 'eat',
#  869: 'hottest',
#  870: 'WAAAAAAyyyyyyyyyy',
#  871: '$',
#  872: 'watch',
#  873: 'than',
#  874: 'its',
#  875: "''",
#  876: 'waiter',
#  877: 'find',
#  878: 'still',
#  879: 'double',
#  880: 'gone',
#  881: 'smaller',
#  882: 'ache',
#  883: 'usual',
#  884: 'Steiners',
#  885: 'BARGAIN',
#  886: 'binge',
#  887: 'doughy',
#  888: 'decent',
#  889: 'Kind',
#  890: 'extraordinary',
#  891: 'they',
#  892: 'amazing',
#  893: 'Unfortunately',
#  894: 'vegetables',
#  895: "'s",
#  896: 'profound',
#  897: 'friends',
#  898: 'flavourful',
#  899: 'meatloaf',
#  900: 'pace',
#  901: 'cashew',
#  902: 'meal',
#  903: 'recommending',
#  904: 'positive',
#  905: 'blown',
#  906: 'talk',
#  907: 'Maine',
#  908: 'family',
#  909: 'one',
#  910: 'crumby',
#  911: 'tough',
#  912: 'worth',
#  913: 'Delight',
#  914: 'deuchebaggery',
#  915: 'Las',
#  916: 'handled',
#  917: 'begin',
#  918: 'Sunday',
#  919: 'You',
#  920: 'return',
#  921: 'tiramisu',
#  922: 'who',
#  923: 'shopping',
#  924: 'BBQ',
#  925: 'margaritas',
#  926: 'uploaded',
#  927: 'others',
#  928: 'no',
#  929: 'providing',
#  930: 'rib',
#  931: 'capers',
#  932: 'dollars',
#  933: 'really',
#  934: 'beat',
#  935: 'stood',
#  936: 'employee',
#  937: 'yucky',
#  938: 'Place',
#  939: 'handed',
#  940: 'recommended',
#  941: 'teeth',
#  942: 'law',
#  943: 'fav',
#  944: 'silently',
#  945: 'instantly',
#  946: 'wagyu',
#  947: 'whole',
#  948: 'andddd',
#  949: 'lack',
#  950: 'simple',
#  951: 'each',
#  952: 'underwhelming',
#  953: 'crust',
#  954: 'lightly',
#  955: 'subpar',
#  956: 'inexpensive',
#  957: 'FLY',
#  958: 'What',
#  959: 'whatsoever',
#  960: '.the',
#  961: 'DELICIOUS',
#  962: 'array',
#  963: 'decor',
#  964: 'relocated',
#  965: 'likes',
#  966: 'gyros',
#  967: 'Mango',
#  968: 'over',
#  969: 'dried',
#  970: 'Of',
#  971: 'Costco',
#  972: 'warnings',
#  973: 'paid',
#  974: 'changing',
#  975: 'Sadly',
#  976: 'chai',
#  977: 'guests',
#  978: 'poor',
#  979: 'ended',
#  980: 'contain',
#  981: 'smelled',
#  982: 'cafe',
#  983: 'Generous',
#  984: 'They',
#  985: 'Area',
#  986: 'brisket',
#  987: 'restaurant',
#  988: 'lovers',
#  989: 'Restaurant',
#  990: 'help',
#  991: 'goat',
#  992: '1.5lb',
#  993: 'platter',
#  994: 'smells',
#  995: 'delicate',
#  996: 'Jenni',
#  997: 'black',
#  998: 'fondue',
#  999: 'bellies',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index_dic[word]]+=1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
