# %% [markdown]
# # 自製智能中文選字系統  (1)

# %%
segments = []
with open('./wiki_zh_small.txt') as fr:
    for line in fr.readlines():
        segments += prepocess_line(line)

# %%
import sys
sys.version
# Out:
# '3.7.3 (default, Mar 27 2019, 16:54:48) \n[Clang 4.0.1 (tags/RELEASE_401/final)]'

# %% [markdown]
# ## 資料前處理

# %% [markdown]
# 確認版本為 python3

# %%
import re

# %%
def prepocess_line(line):
    # 僅僅挑出中文字元，並且斷開不連續的中文字
    regex = r"[\u4E00-\u9FCC]+"
    segments = re.findall(regex, line)
    return segments

# %%
prepocess_line('“英語”一詞源於遷居英格蘭的日耳曼部落盎格魯（），而“盎格魯”得名於')  
# 應該為：['英語', '一詞源於遷居英格蘭的日耳曼部落盎格魯', '而', '盎格魯', '得名於']
# Out:
# ['英語', '一詞源於遷居英格蘭的日耳曼部落盎格魯', '而', '盎格魯', '得名於']

# %% [markdown]
# ## Ngram
#
# 一開始要先計算字詞出現的次數

# %%
from collections import Counter

class Counters:
    def __init__(self, n):
        self.n = n
        self.counters = [Counter() for _ in range(n + 1)]  # 分別代表計算0、1、...個字的出現次數

    def fit(self, segments):
        # 因為 self.counters 分別代表計算0、1、...個字的出現次數
        # 請在此實作利用 segments 以及函式 _skip 來統計次數
        for i in range(1, 1 + self.n):
            for segment in segments:
                self.counters[i] += Counter(self._skip(segment, i))

    def __getitem__(self, k):
        return self.counters[k]

    def _skip(self, segment, n):
        assert n > 0
        if len(segment) < n:
            return []
        shift = n - 1
        for i in range(len(segment) - shift):
            yield segment[i:i+shift+1]

# %%
counters = Counters(n=3)
counters.fit(segments)

# %%
counters.counters[1]
# 應該為： Counter({'': 371373})
# Out:
# Counter({'英': 420,
#          '語': 1416,
#          '又': 210,
#          '稱': 724,
#          '爲': 3637,
#          '文': 1439,
#          '是': 3600,
#          '一': 3659,
#          '種': 891,
#          '西': 1266,
#          '日': 1066,
#          '耳': 49,
#          '曼': 97,
#          '言': 621,
#          '誕': 22,
#          '生': 1116,
#          '於': 2022,
#          '中': 3944,
#          '世': 828,
#          '紀': 320,
#          '早': 211,
#          '期': 769,
#          '的': 13270,
#          '格': 283,
#          '蘭': 213,
#          '如': 805,
#          '今': 327,
#          '具': 319,
#          '有': 3252,
#          '全': 994,
#          '球': 278,
#          '通': 659,
#          '用': 1847,
#          '地': 1756,
#          '位': 701,
#          '詞': 410,
#          '源': 357,
#          '遷': 89,
#          '居': 282,
#          '部': 1009,
#          '落': 75,
#          '盎': 16,
#          '魯': 112,
#          '而': 1055,
#          '得': 599,
#          '名': 824,
#          '臨': 86,
#          '波': 102,
#          '羅': 304,
#          '海': 844,
#          '半': 207,
#          '島': 341,
#          '里': 295,
#          '亞': 557,
#          '弗': 29,
#          '裏': 173,
#          '與': 1088,
#          '最': 936,
#          '相': 613,
#          '近': 248,
#          '彙': 66,
#          '在': 3708,
#          '受': 331,
#          '到': 1065,
#          '了': 1721,
#          '其': 1403,
#          '他': 1148,
#          '族': 860,
#          '大': 2475,
#          '量': 629,
#          '影': 290,
#          '響': 181,
#          '後': 1277,
#          '來': 1144,
#          '尤': 48,
#          '法': 1061,
#          '將': 630,
#          '六': 265,
#          '十': 462,
#          '個': 1875,
#          '國': 4801,
#          '家': 1136,
#          '唯': 69,
#          '官': 196,
#          '方': 1045,
#          '或': 762,
#          '之': 1227,
#          '也': 974,
#          '界': 598,
#          '多': 1118,
#          '它': 420,
#          '愛': 111,
#          '爾': 396,
#          '美': 612,
#          '加': 709,
#          '拿': 54,
#          '澳': 83,
#          '利': 418,
#          '和': 2733,
#          '新': 761,
#          '常': 561,
#          '勒': 78,
#          '比': 576,
#          '非': 351,
#          '洲': 299,
#          '及': 1056,
#          '南': 1056,
#          '分': 1244,
#          '區': 1034,
#          '被': 784,
#          '廣': 572,
#          '泛': 110,
#          '使': 898,
#          '上': 1397,
#          '母': 116,
#          '人': 3201,
#          '口': 556,
#          '第': 767,
#          '三': 625,
#          '僅': 165,
#          '次': 465,
#          '漢': 410,
#          '班': 263,
#          '牙': 258,
#          '學': 1995,
#          '習': 163,
#          '者': 628,
#          '外': 688,
#          '聯': 448,
#          '合': 979,
#          '歐': 224,
#          '盟': 82,
#          '許': 271,
#          '際': 285,
#          '組': 434,
#          '織': 236,
#          '至': 531,
#          '少': 320,
#          '說': 421,
#          '年': 3188,
#          '發': 1378,
#          '展': 438,
#          '史': 483,
#          '公': 934,
#          '元': 846,
#          '撒': 29,
#          '克': 299,
#          '遜': 12,
#          '把': 181,
#          '們': 443,
#          '各': 397,
#          '帶': 227,
#          '不': 1662,
#          '列': 364,
#          '顛': 12,
#          '古': 526,
#          '始': 432,
#          '諾': 117,
#          '征': 42,
#          '服': 159,
#          '這': 1153,
#          '時': 1683,
#          '初': 243,
#          '倫': 78,
#          '敦': 26,
#          '對': 958,
#          '印': 161,
#          '刷': 9,
#          '機': 610,
#          '採': 119,
#          '欽': 9,
#          '定': 955,
#          '版': 436,
#          '聖': 74,
#          '經': 975,
#          '出': 1163,
#          '音': 252,
#          '推': 200,
#          '移': 146,
#          '標': 335,
#          '誌': 46,
#          '代': 1035,
#          '開': 851,
#          '端': 99,
#          '過': 724,
#          '帝': 276,
#          '現': 881,
#          '葉': 66,
#          '傳': 348,
#          '播': 98,
#          '電': 493,
#          '子': 997,
#          '媒': 44,
#          '體': 960,
#          '隨': 162,
#          '着': 156,
#          '取': 261,
#          '超': 153,
#          '級': 289,
#          '已': 400,
#          '成': 1609,
#          '話': 168,
#          '領': 256,
#          '導': 213,
#          '還': 394,
#          '行': 1240,
#          '業': 745,
#          '科': 502,
#          '航': 136,
#          '律': 118,
#          '等': 1113,
#          '很': 330,
#          '屈': 13,
#          '折': 25,
#          '變': 410,
#          '化': 1330,
#          '較': 285,
#          '更': 345,
#          '依': 142,
#          '靠': 43,
#          '助': 132,
#          '動': 679,
#          '序': 329,
#          '表': 615,
#          '達': 341,
#          '複': 102,
#          '雜': 93,
#          '態': 173,
#          '氣': 447,
#          '以': 2298,
#          '疑': 44,
#          '問': 239,
#          '些': 561,
#          '否': 91,
#          '面': 633,
#          '顯': 161,
#          '著': 341,
#          '差': 113,
#          '異': 97,
#          '拼': 35,
#          '所': 810,
#          '同': 957,
#          '但': 582,
#          '能': 1017,
#          '基': 605,
#          '本': 835,
#          '無': 368,
#          '礙': 12,
#          '溝': 18,
#          '交': 229,
#          '流': 304,
#          '支': 324,
#          '朱': 48,
#          '特': 602,
#          '民': 1270,
#          '就': 534,
#          '從': 500,
#          '繼': 113,
#          '承': 93,
#          '下': 728,
#          '據': 371,
#          '編': 339,
#          '記': 262,
#          '載': 97,
#          '左': 96,
#          '右': 83,
#          '羣': 185,
#          '王': 425,
#          '伏': 31,
#          '提': 519,
#          '庚': 6,
#          '邀': 18,
#          '請': 118,
#          '親': 91,
#          '戚': 1,
#          '幫': 41,
#          '抗': 128,
#          '皮': 60,
#          '賜': 10,
#          '予': 44,
#          '東': 947,
#          '土': 232,
#          '作': 1208,
#          '回': 175,
#          '報': 99,
#          '進': 652,
#          '步': 139,
#          '尋': 41,
#          '求': 228,
#          '援': 89,
#          '便': 123,
#          '紛': 31,
#          '前': 751,
#          '終': 113,
#          '建': 624,
#          '立': 633,
#          '七': 145,
#          '森': 42,
#          '布': 152,
#          '麥': 35,
#          '肯': 22,
#          '埃': 83,
#          '塞': 78,
#          '斯': 662,
#          '蘇': 149,
#          '威': 102,
#          '入': 581,
#          '侵': 58,
#          '統': 768,
#          '治': 419,
#          '當': 626,
#          '凱': 19,
#          '主': 1169,
#          '要': 1160,
#          '士': 265,
#          '別': 341,
#          '描': 52,
#          '繪': 21,
#          '九': 111,
#          '堪': 11,
#          '納': 143,
#          '維': 191,
#          '丹': 100,
#          '規': 309,
#          '模': 214,
#          '北': 930,
#          '末': 106,
#          '幾': 184,
#          '乎': 69,
#          '佔': 342,
#          '整': 253,
#          '懸': 20,
#          '殊': 45,
#          '升': 150,
#          '程': 762,
#          '度': 575,
#          '替': 67,
#          '形': 594,
#          '意': 398,
#          '消': 76,
#          '曲': 189,
#          '融': 71,
#          '蝕': 12,
#          '此': 746,
#          '義': 543,
#          '型': 274,
#          '似': 129,
#          '類': 620,
#          '吸': 79,
#          '收': 140,
#          '性': 694,
#          '原': 804,
#          '即': 242,
#          '式': 768,
#          '演': 221,
#          '樣': 245,
#          '貌': 26,
#          '爵': 11,
#          '敏': 29,
#          '寺': 75,
#          '登': 51,
#          '冕': 2,
#          '廉': 17,
#          '百': 287,
#          '內': 776,
#          '君': 150,
#          '貴': 237,
#          '講': 35,
#          '屬': 436,
#          '奧': 72,
#          '教': 1096,
#          '則': 403,
#          '拉': 339,
#          '丁': 88,
#          '淪': 10,
#          '平': 581,
#          '農': 182,
#          '奴': 23,
#          '因': 723,
#          '重': 667,
#          '場': 354,
#          '強': 204,
#          '烈': 27,
#          '賤': 3,
#          '缺': 96,
#          '乏': 28,
#          '範': 142,
#          '視': 216,
#          '約': 400,
#          '束': 69,
#          '迅': 30,
#          '速': 244,
#          '丟': 12,
#          '失': 128,
#          '品': 252,
#          '貝': 52,
#          '武': 340,
#          '夫': 87,
#          '坎': 3,
#          '伯': 119,
#          '故': 124,
#          '事': 475,
#          '集': 267,
#          '莎': 45,
#          '處': 340,
#          '繁': 49,
#          '榮': 32,
#          '線': 309,
#          '殖': 64,
#          '雖': 113,
#          '然': 603,
#          '藝': 158,
#          '復': 77,
#          '興': 143,
#          '希': 243,
#          '臘': 177,
#          '心': 286,
#          '由': 867,
#          '圍': 98,
#          '極': 163,
#          '可': 1158,
#          '避': 46,
#          '免': 169,
#          '再': 146,
#          '層': 172,
#          '準': 271,
#          '除': 204,
#          '紐': 40,
#          '自': 1066,
#          '獨': 160,
#          '己': 139,
#          '像': 145,
#          '某': 113,
#          '都': 633,
#          '點': 320,
#          '明': 501,
#          '寫': 301,
#          '小': 379,
#          '般': 163,
#          '術': 404,
#          '構': 283,
#          '辭': 30,
#          '書': 621,
#          '例': 325,
#          '牛': 45,
#          '津': 44,
#          '典': 161,
#          '技': 213,
#          '章': 89,
#          '共': 614,
#          '二': 445,
#          '戰': 410,
#          '理': 840,
#          '解': 344,
#          '純': 58,
#          '潔': 6,
#          '看': 118,
#          '正': 417,
#          '概': 100,
#          '念': 166,
#          '逐': 95,
#          '漸': 82,
#          '只': 285,
#          '指': 335,
#          '論': 452,
#          '衆': 127,
#          '介': 61,
#          '反': 327,
#          '產': 850,
#          '並': 754,
#          '且': 240,
#          '益': 54,
#          '擴': 108,
#          '腦': 131,
#          '軟': 360,
#          '件': 358,
#          '兩': 403,
#          '先': 236,
#          '商': 226,
#          '域': 315,
#          '力': 392,
#          '突': 124,
#          '貢': 45,
#          '獻': 65,
#          '易': 214,
#          '做': 130,
#          '億': 221,
#          '陸': 192,
#          '普': 202,
#          '遍': 63,
#          '接': 324,
#          '德': 460,
#          '香': 133,
#          '港': 219,
#          '門': 265,
#          '臺': 568,
#          '灣': 260,
#          '韓': 133,
#          '校': 317,
#          '必': 177,
#          '修': 164,
#          '課': 43,
#          '愈': 13,
#          '往': 170,
#          '工': 716,
#          '專': 190,
#          '信': 284,
#          '息': 85,
#          '簡': 169,
#          '飛': 54,
#          '廠': 57,
#          '企': 53,
#          '手': 174,
#          '冊': 18,
#          '遠': 102,
#          '礎': 86,
#          '授': 92,
#          '華': 679,
#          '育': 321,
#          '高': 851,
#          '階': 74,
#          '段': 126,
#          '選': 228,
#          '擇': 54,
#          '制': 362,
#          '考': 228,
#          '試': 122,
#          '畢': 38,
#          '證': 155,
#          '關': 434,
#          '係': 86,
#          '密': 109,
#          '切': 69,
#          '俄': 67,
#          '直': 357,
#          '革': 145,
#          '命': 222,
#          '目': 376,
#          '待': 40,
#          '向': 270,
#          '絕': 86,
#          '數': 1117,
#          '會': 1456,
#          '均': 233,
#          '需': 185,
#          '水': 458,
#          '亦': 143,
#          '應': 480,
#          '緣': 17,
#          '坊': 6,
#          '間': 663,
#          '參': 163,
#          '補': 52,
#          '司': 247,
#          '徵': 75,
#          '檻': 2,
#          '檢': 72,
#          '系': 664,
#          '聲': 109,
#          '研': 312,
#          '究': 285,
#          '慮': 33,
#          '歷': 327,
#          '每': 215,
#          '沒': 267,
#          '決': 245,
#          '認': 481,
#          '妨': 3,
#          '仍': 140,
#          '互': 77,
#          '圖': 296,
#          '功': 243,
#          '那': 157,
#          '麼': 93,
#          '去': 191,
#          '陰': 87,
#          '陽': 291,
#          '調': 222,
#          '固': 61,
#          '順': 78,
#          '朝': 523,
#          '析': 47,
#          '貓': 7,
#          '尾': 41,
#          '根': 228,
#          '綴': 13,
#          '任': 410,
#          '換': 89,
#          '詩': 85,
#          '示': 263,
#          '保': 334,
#          '留': 101,
#          '起': 560,
#          '幅': 42,
#          '減': 67,
#          '舊': 66,
#          '句': 97,
#          '置': 141,
#          '字': 602,
#          '包': 495,
#          '括': 349,
#          '連': 165,
#          '短': 51,
#          '優': 74,
#          '雅': 39,
#          '造': 249,
#          '詣': 2,
#          '運': 390,
#          '矯': 3,
#          '飾': 36,
#          '刻': 50,
#          '賣': 25,
#          '弄': 1,
#          '喬': 16,
#          '政': 682,
#          '透': 59,
#          '徹': 17,
#          '單': 282,
#          '挑': 12,
#          '微': 305,
#          '妙': 9,
#          '夠': 110,
#          '觀': 218,
#          '活': 285,
#          '庭': 54,
#          '醫': 94,
#          '巨': 40,
#          '容': 215,
#          '引': 144,
#          '輸': 93,
#          '另': 214,
#          '俚': 2,
#          '含': 246,
#          '靈': 95,
#          '確': 164,
#          '師': 122,
#          '醒': 6,
#          '社': 237,
#          '龐': 69,
#          '總': 551,
#          '計': 468,
#          '果': 255,
#          '估': 35,
#          '須': 117,
#          '判': 36,
#          '斷': 143,
#          '哪': 10,
#          '算': 297,
#          '權': 276,
#          '何': 153,
#          '湧': 8,
#          '錄': 130,
#          '五': 345,
#          '萬': 592,
#          '條': 298,
#          '寬': 32,
#          '鬆': 8,
#          '廢': 37,
#          '棄': 30,
#          '疇': 9,
#          '舉': 166,
#          '身': 221,
#          '夏': 89,
#          '夷': 29,
#          '創': 200,
#          '思': 181,
#          '庫': 102,
#          '備': 156,
#          '資': 289,
#          '料': 163,
#          '藉': 26,
#          '曾': 229,
#          '致': 156,
#          '借': 19,
#          '告': 81,
#          '八': 180,
#          '查': 122,
#          '結': 345,
#          '嚴': 101,
#          '按': 101,
#          '照': 121,
#          '難': 82,
#          '掌': 152,
#          '握': 22,
#          '才': 122,
#          '知': 281,
#          '道': 442,
#          '符': 191,
#          '號': 271,
#          '歌': 497,
#          '劇': 106,
#          '節': 160,
#          '戲': 192,
#          '效': 75,
#          '持': 285,
#          '韻': 6,
#          '仿': 19,
#          '見': 185,
#          '象': 178,
#          '盛': 60,
#          '越': 162,
#          '忘': 9,
#          '甚': 87,
#          '候': 133,
#          '裝': 114,
#          '腔': 7,
#          '勢': 123,
#          '該': 261,
#          '遵': 36,
#          '循': 25,
#          '閉': 24,
#          '掉': 21,
#          '摘': 2,
#          '續': 166,
#          '排': 195,
#          '省': 1163,
#          '略': 92,
#          '風': 152,
#          '情': 229,
#          '濃': 27,
#          '批': 98,
#          '評': 89,
#          '卻': 91,
#          '偏': 30,
#          '精': 126,
#          '週': 154,
#          '刊': 24,
#          '孫': 358,
#          '臏': 181,
#          '躍': 33,
#          '軍': 605,
#          '兵': 254,
#          '物': 746,
#          '刑': 25,
#          '阿': 281,
#          '鄄': 3,
#          '山': 712,
#          '穀': 7,
#          '縣': 339,
#          '城': 311,
#          '鎮': 74,
#          '菏': 2,
#          '澤': 42,
#          '市': 633,
#          '涓': 50,
#          '窗': 38,
#          '迫': 32,
#          '害': 47,
#          '遭': 50,
#          '殘': 15,
#          '疾': 40,
#          '齊': 161,
#          '投': 98,
#          '奔': 20,
#          '輔': 37,
#          '佐': 9,
#          '田': 113,
#          '忌': 50,
#          '擊': 124,
#          '敗': 57,
#          '桂': 23,
#          '陵': 101,
#          '馬': 428,
#          '勝': 89,
#          '奠': 18,
#          '霸': 17,
#          '清': 235,
#          '鬥': 30,
#          '志': 66,
#          '智': 218,
#          '唐': 179,
#          '宗': 365,
#          '四': 354,
#          '卓': 12,
#          '供': 185,
#          '奉': 48,
#          '廟': 32,
#          '宋': 117,
#          '徽': 137,
#          '追': 53,
#          '尊': 41,
#          '春': 134,
#          '秋': 66,
#          '吳': 258,
#          '祖': 90,
#          '陳': 60,
#          '完': 224,
#          '宇': 37,
#          '討': 54,
#          '伐': 28,
#          '莒': 3,
#          '景': 101,
#          '姓': 37,
#          '改': 394,
#          '封': 52,
#          '樂': 177,
#          '安': 541,
#          '食': 103,
#          '邑': 11,
#          '嬀': 1,
#          '氏': 55,
#          '憑': 14,
#          '躲': 3,
#          '鮑': 8,
#          '亂': 38,
#          '馳': 3,
#          '敵': 43,
#          '操': 107,
#          '父': 63,
#          '距': 39,
#          '吻': 4,
#          '壬': 2,
#          '林': 365,
#          '述': 127,
#          '碑': 31,
#          '衛': 149,
#          '拜': 61,
#          '仕': 7,
#          '魏': 154,
#          '擔': 57,
#          '惠': 36,
#          '暗': 27,
#          '派': 144,
#          '監': 74,
#          '嫉': 6,
#          '妒': 6,
#          '捏': 2,
#          '罪': 26,
#          '黥': 2,
#          '砍': 6,
#          '雙': 89,
#          '足': 131,
#          '臉': 4,
#          '刺': 45,
#          '想': 144,
#          '埋': 10,
#          '首': 257,
#          '梁': 39,
#          '河': 414,
#          '徒': 92,
#          '份': 187,
#          '祕': 59,
#          '打': 120,
#          '覺': 43,
#          '凡': 18,
#          '偷': 15,
#          '車': 140,
#          '逃': 26,
#          '賞': 28,
#          '識': 194,
#          '寄': 14,
#          '客': 199,
#          '諸': 93,
#          '賽': 73,
#          '設': 439,
#          '金': 435,
#          '賭': 13,
#          '注': 88,
#          '腳': 20,
#          '議': 367,
#          '千': 164,
#          '讓': 120,
#          '負': 70,
#          '贏': 8,
#          '振': 17,
#          '薦': 15,
#          '給': 172,
#          '趙': 64,
#          '攻': 126,
#          '奪': 33,
#          '漆': 4,
#          '富': 142,
#          '丘': 69,
#          '長': 815,
#          '垣': 6,
#          '招': 30,
#          '干': 37,
#          '涉': 29,
#          '邯': 13,
#          '鄲': 13,
#          '楚': 87,
#          '救': 58,
#          '召': 47,
#          '臣': 26,
#          '鄒': 8,
#          '幹': 57,
#          '朋': 19,
#          '路': 405,
#          '襄': 23,
#          '睢': 1,
#          '疲': 8,
#          '勞': 53,
#          '趁': 11,
#          '破': 134,
#          '既': 35,
#          '削': 14,
#          '弱': 47,
#          '率': 216,
#          '倉': 7,
#          '隊': 165,
#          '酷': 4,
#          '拒': 17,
#          '坐': 14,
#          '蓬': 7,
#          '帳': 8,
#          '謀': 22,
#          '劃': 209,
#          '策': 86,
#          '茬': 1,
#          '茌': 1,
#          '邊': 120,
#          '境': 225,
#          '阻': 22,
#          '止': 109,
#          '耗': 12,
#          '老': 107,
#          '憊': 5,
#          '防': 80,
#          '務': 248,
#          '空': 210,
#          '虛': 38,
#          '搗': 3,
#          '撤': 34,
#          '佯': 5,
#          '張': 174,
#          '池': 27,
#          '管': 236,
#          '轄': 130,
#          '途': 42,
#          '糧': 45,
#          '好': 131,
#          '迷': 23,
#          '惑': 3,
#          '揮': 29,
#          '錯': 58,
#          '拔': 54,
#          '營': 81,
#          '淄': 4,
#          '博': 128,
#          '輕': 83,
#          '郊': 4,
#          '激': 64,
#          '怒': 8,
#          '辦': 113,
#          '輜': 2,
#          '急': 21,
#          '晝': 3,
#          '夜': 29,
#          '兼': 53,
#          '擒': 4,
#          '獲': 111,
#          '潰': 12,
#          '捨': 4,
#          '停': 48,
#          '休': 25,
#          '侯': 64,
#          '漳': 18,
#          '釋': 104,
#          '放': 251,
#          '穰': 3,
#          '疵': 1,
#          '汝': 6,
#          '州': 579,
#          '霍': 12,
#          '退': 41,
#          '孔': 61,
#          '昭': 14,
#          '詢': 19,
#          '遲': 8,
#          '丏': 1,
#          '晚': 54,
#          '轉': 201,
#          '未': 168,
#          '危': 25,
#          '旦': 24,
#          '夕': 4,
#          '贊': 16,
#          '協': 179,
#          '恃': 3,
#          '朌': 1,
#          '嬰': 6,
#          '副': 57,
#          '襲': 28,
#          '忙': 9,
#          '返': 35,
#          '勇': 65,
#          '況': 111,
#          '怯': 3,
#          '誘': 13,
#          '深': 90,
#          '圈': 41,
#          '殲': 4,
#          '滅': 41,
#          '令': 127,
#          '天': 518,
#          '飯': 16,
#          '竈': 2,
#          '我': 201,
#          '懦': 2,
#          '跑': 10,
#          ...})

# %%
class Ngram:
    def __init__(self, n, counters):
        assert n <= counters.n
        self.n = n
        self.major_counter = counters[n]
        self.minor_counter = counters[n-1]

    def predict_proba(self, prefix='', top_k=5):
        assert len(prefix) >= self.n - 1
        # 使用 Ngram 的公式計算出下一個字出現的機率
        # 輸出為機率與字的tuple列表，詳見下方輸出範例
        reference = prefix[-(self.n - 1):] if self.n > 1 else ''
        count_referecne = self.minor_counter[reference]
        probs = []
        for key, count in dict(self.major_counter).items():
            if key.startswith(reference):
                prob = count / count_referecne
                probs.append((prob, key[-1]))
        sorted_probs = sorted(probs, reverse=True)
        
        # END YOUR CODE
        return sorted_probs[:top_k] if top_k > 0 else sorted_probs

    def get_proba_dict(self, prefix=''):
        return {word: prob for prob, word in self.predict_proba(prefix, top_k=-1)}

# %%
unigram = Ngram(1, counters)

# %%
unigram.predict_proba('我思')
# 應該為：[(0.035732269174118744, '的'),
#         (0.012927703414087723, '國'),
#         (0.010620050461395955, '中'),
#         (0.009984570768472667, '在'),
#         (0.009852627950874188, '一')]
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-122-dd9c6bc0c1db> in <module>
# ----> 1 unigram.predict_proba('我思')
#       2 # 應該為：[(0.035732269174118744, '的'),
#       3 #         (0.012927703414087723, '國'),
#       4 #         (0.010620050461395955, '中'),
#       5 #         (0.009984570768472667, '在'),
#
# <ipython-input-120-6a844127fb8a> in predict_proba(self, prefix, top_k)
#      15         for key, count in dict(self.major_counter).items():
#      16             if key.startswith(reference):
# ---> 17                 prob = count / count_referecne
#      18                 probs.append((prob, key[-1]))
#      19         sorted_probs = sorted(probs, reverse=True)
#
# ZeroDivisionError: division by zero

# %%
bigram = Ngram(2, counters)
trigram = Ngram(3, counters)

# %% [markdown]
# ## 使用Ngram來建立第一版選字系統

# %%
class ChineseWordRecommenderV1:
    def __init__(self, unigram, bigram, trigram):
        self.unigram = unigram
        self.bigram = bigram
        self.trigram = trigram
    
    def predict_proba(self, prefix='', top_k=5):
        # 使用Ngram來建立選字系統
        if len(prefix) >= 2:
            return self.trigram.predict_proba(prefix, top_k)
        elif len(prefix) >= 1:
            return self.bigram.predict_proba(prefix, top_k)
        elif len(prefix) == 0
            return self.unigram.predict_proba(prefix, top_k)

# %%
model = ChineseWordRecommenderV1(unigram, bigram, trigram)

# %%
probs = model.predict_proba('我思', top_k=10)
probs
# Out:
# [(0.75, '故'), (0.25, '維')]

# %% [markdown]
# ## Demo

# %%
# !pip install -U pip
# !pip install -q ipywidgets
# Out:
# Requirement already up-to-date: pip in /Users/ycchen/.pyenv/versions/3.6.5/lib/python3.6/site-packages (20.1.1)

# %%
import ipywidgets as widgets

text = widgets.Textarea()
label = widgets.Label()
display(label, text)

def func(change):
    probs = model.predict_proba(change.new, top_k=10)
    label.value = ' ' + '\t'.join([word for prob, word in probs])

text.observe(func, names='value')
# Out:
# Label(value='')
# Textarea(value='')
