# %% [markdown]
# ## 作業目標：運用課程所學，操作字串達到預期輸出

# %% [markdown]
# * 自行尋找一篇超過100字的文章
#     * 首先運用結巴斷詞，自行新增字典使得斷詞更為正確
#     * 使用jieba 完成 PoS Taggin
#     * 新增的詞也必須賦予詞性

# %% [markdown]
# ---

# %%
import jieba
import jieba.posseg as pseg
jieba.set_dictionary('dict.txt.big')

# %% [markdown]
# ---

# %%
sentence = '''後來，胡塔加隆壓抑著害怕心情，將這塊約2公斤重的岩石挖出來，他告訴BBC印尼文分部：「當我把石頭拿起時，它依然很溫暖......當時我就想，這可能是來自天空的隕石—不可能有人把這麼大的石頭從屋頂上丟下來。」

胡塔加隆興奮地把隕石的照片分享到臉書（Facebook），藉由社群媒體的傳播力量，這個離奇的故事傳出了他所在的村莊、傳出了蘇門答臘（Sumatra）與全印尼，最後受到國際關注，也毫不意外地引起各國收藏家們的興趣。

隕石收藏家
BBC指出，隕石除了具有科學研究上的意義外，其乘載超過40億年的悠久歷史，彷彿訴說著宇宙的奧秘，向來是是諸多收藏家心目中的夢幻逸品，但當時在新冠疫情肆虐下，全球飛航近乎停擺，幾位美國潛在買家於是商請現居印尼的美國商人柯林斯（Jared Collins）協助。柯林斯其後抵達蘇門答臘與胡塔加隆見面，確認隕石的真實性，並確保其受到妥善存放。

「能有機會擁有太陽系初期就存在的遺跡，實在令人相當興奮，」柯林斯告訴BBC，他馬上注意到這塊隕石漆黑的內層構造、帶有一層淺淺的棕色，以及滿布坑坑洞洞的外表，「這都是它在大氣中穿梭時所造就的......它還有一種非常特殊的氣味，無法用言語形容。」

透過柯林斯的中介，胡塔加隆與美國賣家達成協議，順利將隕石售出。雖然隕石實際的售價並未公開，雙方都強調價碼十分公正，沒有人被敲竹槓；但BBC指出，胡塔加隆的隕石致富夢恐怕不如一開始想像得如此美好—出現在他家屋頂的隕石絕對不值180萬美元。

'''

# %%
import re
import string
chinese_punctuation = "！？｡。＂＃＄％＆＇()＊＋，－／：；＜＝＞＠［＼］＾＿｀｛｜｝～｟｠｢｣､、〃》「」『』【】〔〕〖〗〘〙〚〛〜〝〞〟〰〾〿–—‘’‛“”„‟…‧﹏."
removed_ASCII_punc = re.sub(rf"[{''.join(string.punctuation)}]+", "", sentence)
removed_chinese_punc_sentence = re.sub(rf"[{chinese_punctuation}]+", "", removed_ASCII_punc)
removed_english_sentence = re.sub(rf"[a-zA-Z]+", r"", removed_chinese_punc_sentence)

# %%
removed_english_sentence
# Out:
# '後來胡塔加隆壓抑著害怕心情將這塊約2公斤重的岩石挖出來他告訴印尼文分部當我把石頭拿起時它依然很溫暖當時我就想這可能是來自天空的隕石不可能有人把這麼大的石頭從屋頂上丟下來\n\n胡塔加隆興奮地把隕石的照片分享到臉書（）藉由社群媒體的傳播力量這個離奇的故事傳出了他所在的村莊傳出了蘇門答臘（）與全印尼最後受到國際關注也毫不意外地引起各國收藏家們的興趣\n\n隕石收藏家\n指出隕石除了具有科學研究上的意義外其乘載超過40億年的悠久歷史彷彿訴說著宇宙的奧秘向來是是諸多收藏家心目中的夢幻逸品但當時在新冠疫情肆虐下全球飛航近乎停擺幾位美國潛在買家於是商請現居印尼的美國商人柯林斯（ ）協助柯林斯其後抵達蘇門答臘與胡塔加隆見面確認隕石的真實性並確保其受到妥善存放\n\n能有機會擁有太陽系初期就存在的遺跡實在令人相當興奮柯林斯告訴他馬上注意到這塊隕石漆黑的內層構造帶有一層淺淺的棕色以及滿布坑坑洞洞的外表這都是它在大氣中穿梭時所造就的它還有一種非常特殊的氣味無法用言語形容\n\n透過柯林斯的中介胡塔加隆與美國賣家達成協議順利將隕石售出雖然隕石實際的售價並未公開雙方都強調價碼十分公正沒有人被敲竹槓但指出胡塔加隆的隕石致富夢恐怕不如一開始想像得如此美好出現在他家屋頂的隕石絕對不值180萬美元\n\n'

# %% [markdown]
# ## 新增字典

# %%
new_word_dicts = [
    {"word":"岩石", "freq":10, "tag":"nz"},
    {"word":"岩漿", "freq":10, "tag":"nz"},
    {"word":"挖", "freq":10, "tag":"v"},
    {"word":"臉書", "freq":10, "tag":"nz"},
    {"word":"乘載", "freq":10, "tag":"v"},
    {"word":"奧秘", "freq":10, "tag":"nz"}
]
for new_word_dict in new_word_dicts:
    jieba.add_word(word=new_word_dict["word"], freq=new_word_dict["freq"], tag=new_word_dict["tag"])

# %%
import re
import string
chinese_punctuation = "！？｡。＂＃＄％＆＇()＊＋，－／：；＜＝＞＠［＼］＾＿｀｛｜｝～｟｠｢｣､、〃》「」『』【】〔〕〖〗〘〙〚〛〜〝〞〟〰〾〿–—‘’‛“”„‟…‧﹏."
removed_ASCII_punc_new_words = re.sub(rf"[{''.join(string.punctuation)}]+", "", new_words)
removed_chinese_punc_new_words = re.sub(rf"[{chinese_punctuation}]+", "", removed_ASCII_punc_new_words)
removed_english_new_words = re.sub(rf"[a-zA-Z]+", r"", removed_chinese_punc_new_words)

# %%
print("output 精確模式 (original): {}".format('|'.join(jieba.cut(sentence, cut_all=False, HMM=False))))
# Out:
# output 精確模式: 後來|，|胡|塔|加|隆|壓抑|著|害怕|心情|，|將|這塊|約|2|公斤|重|的|岩石|挖出來|，|他|告訴|BBC|印尼|文|分部|：|「|當|我|把|石頭|拿|起|時|，|它|依然|很|溫暖|.|.|.|.|.|.|當時|我|就|想|，|這|可能|是|來自|天空|的|隕石|—|不|可能|有人|把|這麼|大|的|石頭|從|屋頂|上|丟下來|。|」|
# |
# |胡|塔|加|隆|興奮|地|把|隕石|的|照片|分享|到|臉|書|（|Facebook|）|，|藉由|社群|媒體|的|傳播|力量|，|這個|離奇|的|故事|傳出|了|他|所在|的|村莊|、|傳出|了|蘇門答臘|（|Sumatra|）|與|全|印尼|，|最後|受到|國際|關注|，|也|毫不|意外|地|引起|各國|收藏家|們|的|興趣|。|
# |
# |隕石|收藏家|
# |BBC|指出|，|隕石|除了|具有|科學研究|上|的|意義|外|，|其|乘|載|超過|40|億年|的|悠久|歷史|，|彷彿|訴說|著|宇宙|的|奧|秘|，|向來|是|是|諸多|收藏家|心目|中|的|夢幻|逸品|，|但|當時|在|新|冠|疫情|肆虐|下|，|全球|飛航|近乎|停擺|，|幾位|美國|潛在|買家|於是|商請|現居|印尼|的|美國|商人|柯林斯|（|Jared| |Collins|）|協助|。|柯林斯|其後|抵達|蘇門答臘|與|胡|塔|加|隆|見面|，|確認|隕石|的|真實性|，|並|確保|其|受到|妥善|存放|。|
# |
# |「|能|有|機會|擁有|太陽系|初期|就|存在|的|遺|跡|，|實在|令人|相當|興奮|，|」|柯林斯|告訴|BBC|，|他|馬上|注意|到|這塊|隕石|漆黑|的|內層|構造|、|帶有|一層|淺淺的|棕色|，|以及|滿布|坑坑洞洞|的|外表|，|「|這|都|是|它|在|大氣|中|穿梭|時|所|造就|的|.|.|.|.|.|.|它|還有|一種|非常|特殊|的|氣味|，|無法|用|言語|形容|。|」|
# |
# ...

# %%
print("output 精確模式: (add new words){}".format('|'.join(jieba.cut(sentence, cut_all=False, HMM=False))))
# Out:
# output 精確模式: (add new words)後來|，|胡|塔|加|隆|壓抑|著|害怕|心情|，|將|這塊|約|2|公斤|重|的|岩石|挖出來|，|他|告訴|BBC|印尼|文|分部|：|「|當|我|把|石頭|拿|起|時|，|它|依然|很|溫暖|.|.|.|.|.|.|當時|我|就|想|，|這|可能|是|來自|天空|的|隕石|—|不|可能|有人|把|這麼|大|的|石頭|從|屋頂|上|丟下來|。|」|
# |
# |胡|塔|加|隆|興奮|地|把|隕石|的|照片|分享|到|臉書|（|Facebook|）|，|藉由|社群|媒體|的|傳播|力量|，|這個|離奇|的|故事|傳出|了|他|所在|的|村莊|、|傳出|了|蘇門答臘|（|Sumatra|）|與|全|印尼|，|最後|受到|國際|關注|，|也|毫不|意外|地|引起|各國|收藏家|們|的|興趣|。|
# |
# |隕石|收藏家|
# |BBC|指出|，|隕石|除了|具有|科學研究|上|的|意義|外|，|其|乘載|超過|40|億年|的|悠久|歷史|，|彷彿|訴說|著|宇宙|的|奧秘|，|向來|是|是|諸多|收藏家|心目|中|的|夢幻|逸品|，|但|當時|在|新|冠|疫情|肆虐|下|，|全球|飛航|近乎|停擺|，|幾位|美國|潛在|買家|於是|商請|現居|印尼|的|美國|商人|柯林斯|（|Jared| |Collins|）|協助|。|柯林斯|其後|抵達|蘇門答臘|與|胡|塔|加|隆|見面|，|確認|隕石|的|真實性|，|並|確保|其|受到|妥善|存放|。|
# |
# |「|能|有|機會|擁有|太陽系|初期|就|存在|的|遺|跡|，|實在|令人|相當|興奮|，|」|柯林斯|告訴|BBC|，|他|馬上|注意|到|這塊|隕石|漆黑|的|內層|構造|、|帶有|一層|淺淺的|棕色|，|以及|滿布|坑坑洞洞|的|外表|，|「|這|都|是|它|在|大氣|中|穿梭|時|所|造就|的|.|.|.|.|.|.|它|還有|一種|非常|特殊|的|氣味|，|無法|用|言語|形容|。|」|
# |
# ...

# %% [markdown]
# ## Taggin

# %%
words = pseg.cut(sentence,)
for word, flag in words:
    print(word, flag)
# Out:
# 後來 x
# ， x
# 胡塔加隆 nr
# 壓抑 x
# 著 n
# 害怕 v
# 心情 n
# ， x
# 將 zg
# 這塊 x
# 約 d
# 2 m
# 公斤 q
# 重 a
# 的 uj
# 岩石 nz
# 挖出來 x
# ， x
# 他 r
# 告訴 x
# BBC eng
# 印尼 ns
# 文 n
# 分部 n
# ： x
# 「 x
# 當 p
# 我 r
# 把 p
# 石頭 x
# 拿起 v
# 時 n
# ， x
# 它 r
# 依然 d
# 很 zg
# 溫暖 x
# ...... m
# 當時 x
# 我 r
# 就 d
# 想 v
# ， x
# 這 zg
# 可能 v
# 是 v
# 來自 x
# 天空 n
# 的 uj
# 隕石 x
# — x
# 不 d
# 可能 v
# 有人 r
# 把 p
# 這麼 x
# 大 a
# 的 uj
# 石頭 x
# 從 zg
# 屋頂 x
# 上 f
# 丟下來 x
# 。 x
# 」 x
#
#  x
#
#  x
# 胡塔加隆 nr
# 興奮 x
# 地 uv
# 把 p
# 隕石 x
# 的 uj
# 照片 n
# 分享 v
# 到 v
# 臉書 nz
# （ x
# Facebook eng
# ） x
# ， x
# 藉由 nr
# 社群 n
# 媒體 x
# 的 uj
# 傳播 x
# 力量 n
# ， x
# 這個 x
# 離奇 x
# 的 uj
# 故事 n
# 傳出 x
# 了 ul
# 他 r
# 所在 b
# 的 uj
# 村莊 x
# 、 x
# 傳出 x
# 了 ul
# 蘇門答臘 x
# （ x
# Sumatra eng
# ） x
# 與 p
# 全 n
# 印尼 ns
# ， x
# 最後 x
# 受到 v
# 國際 x
# 關注 x
# ， x
# 也 d
# 毫不 d
# 意外 a
# 地 uv
# 引起 v
# 各國 x
# 收藏家 n
# 們 k
# 的 uj
# 興趣 x
# 。 x
#
#  x
#
#  x
# 隕石 x
# 收藏家 n
#
#  x
# BBC eng
# 指出 v
# ， x
# 隕石 x
# 除了 p
# 具有 v
# 科學研究 x
# 上 f
# 的 uj
# 意義 x
# 外 f
# ， x
# 其 r
# ...
